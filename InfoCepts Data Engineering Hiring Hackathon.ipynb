# %% [markdown]
# # InfoCepts Data Engineering Hiring Hackathon

# %%
#this is to find where spark is installed on my system
import findspark
findspark.init()

# %%
#import pyspark
import pyspark
from pyspark.sql import SparkSession
import pandas as pd
from datetime import datetime
from pyspark.sql.types import *
from pyspark.sql import functions as F
from pyspark.sql.functions import udf,col
import xml.etree.ElementTree as ET
import xmltodict
import csv

# %%
#start the spark builder
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('test') \
    .getOrCreate()

# %% [markdown]
# ## Data preparation (converting xml to csv as xml file too large for pandas)

# %%
df_file_location = '/home/deen/Desktop/infoproject/info hackathon/InfoCept Participants Data/InfoCept Participants Data/infocept_xml_data_.xml'

# %%
# Reading xml file
with open(df_file_location, 'r') as file:
    filedata = file.read()

# %%
# Converting xml to python dictionary (ordered dict)    
data_dict = xmltodict.parse(filedata)

# %%
#we iterate true to match the r
retail_data_list = [dict(x) for x in data_dict["data"]["row"]]

# %%
retail_data_list
# Out:
# [{'index': '0',
#   'user_session': '8b69208e-7c64-422d-b670-5b9d82d25606',
#   'total_clicks': '7',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.5115078598666931',
#   'mean_dwell': '5.995877926032465',
#   'total_duration': '166.71117484170466',
#   'click_rate': '0.0725244742626448',
#   'day_of_week': '1',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013560982667520',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1030297',
#   'cat_views_freqs': '0.2678021521567366',
#   'prod_views_freqs': '0.0009451491729694',
#   'cat_buys_freqs': '0.2337402332570538',
#   'prod_buys_freqs': '0.0006900279353354',
#   'is_purchase': '0',
#   'start_time_ts': 'October 07, 2019 Monday, 00:08:28',
#   'end_time_ts': 'October 26, 2019 Saturday, 16:08:29'},
#  {'index': '1',
#   'user_session': '8068596c-a2b8-46ca-8791-e10d70520a1f',
#   'total_clicks': '7',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '7.626575685782095',
#   'mean_dwell': '3.5291647514620803',
#   'total_duration': '0.4341847739325721',
#   'click_rate': '0.2042478218468011',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013602328876544',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '36083228',
#   'cat_views_freqs': '0.1409251198603834',
#   'prod_views_freqs': '0.0009458164456021',
#   'cat_buys_freqs': '0.4550292185895114',
#   'prod_buys_freqs': '0.0006896519366427',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 15:08:40',
#   'end_time_ts': 'October 15, 2019 Tuesday, 20:03:18'},
#  {'index': '2',
#   'user_session': '4d153217-e06d-4581-8924-702c7f757610',
#   'total_clicks': '2',
#   'total_items': '22',
#   'total_cats': '1',
#   'max_dwell': '3.0956374607750474',
#   'mean_dwell': '180.97751575631065',
#   'total_duration': '0.935320447421298',
#   'click_rate': '0.0459822489852758',
#   'day_of_week': '4',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2175094838038844672',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1002263',
#   'cat_views_freqs': '0.0002938263260135',
#   'prod_views_freqs': '0.0009453910736723',
#   'cat_buys_freqs': '9.102016583495409e-08',
#   'prod_buys_freqs': '0.0006900877869533',
#   'is_purchase': '0',
#   'start_time_ts': 'October 14, 2019 Monday, 21:17:24',
#   'end_time_ts': 'October 23, 2019 Wednesday, 21:56:30'},
#  {'index': '3',
#   'user_session': 'e65a6869-fb45-4f34-8482-c80278676d0f',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '1.0891282494607244',
#   'mean_dwell': '4.33828036473822',
#   'total_duration': '0.4170550606952284',
#   'click_rate': '0.0284757557656416',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013568140556288',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '1003257',
#   'cat_views_freqs': '0.1501068135750563',
#   'prod_views_freqs': '0.0009449909696147',
#   'cat_buys_freqs': '0.4550279409441771',
#   'prod_buys_freqs': '0.0007388217985755',
#   'is_purchase': '0',
#   'start_time_ts': 'October 05, 2019 Saturday, 21:54:13',
#   'end_time_ts': 'October 17, 2019 Thursday, 13:54:29'},
#  {'index': '4',
#   'user_session': 'd8206742-06d7-42a2-8163-d70f9dd6cb18',
#   'total_clicks': '5',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.3298140458866487',
#   'mean_dwell': '3.1808911181790744',
#   'total_duration': '2.485719583259645',
#   'click_rate': '0.0948123574889597',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013558410492160',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '13728056',
#   'cat_views_freqs': '0.2677838216567613',
#   'prod_views_freqs': '0.0009450520425059',
#   'cat_buys_freqs': '0.4550284240027174',
#   'prod_buys_freqs': '0.0006895188328313',
#   'is_purchase': '0',
#   'start_time_ts': 'October 09, 2019 Wednesday, 13:33:22',
#   'end_time_ts': 'October 29, 2019 Tuesday, 11:51:04'},
#  {'index': '5',
#   'user_session': '3e095d1f-cc89-4c2a-9fe9-346f0878ee72',
#   'total_clicks': '4',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.8360159537591165',
#   'mean_dwell': '4.297781782486854',
#   'total_duration': '0.4423375541495495',
#   'click_rate': '0.0589005592142396',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013557948264960',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1003156',
#   'cat_views_freqs': '8.490897803682673e-05',
#   'prod_views_freqs': '0.0009453624766345',
#   'cat_buys_freqs': '0.0105364173246436',
#   'prod_buys_freqs': '0.000689549194347',
#   'is_purchase': '0',
#   'start_time_ts': 'October 04, 2019 Friday, 13:12:56',
#   'end_time_ts': 'October 17, 2019 Thursday, 08:19:35'},
#  {'index': '6',
#   'user_session': 'ece2a8db-2d67-4570-bcde-7e732dbd3d93',
#   'total_clicks': '2',
#   'total_items': '7',
#   'total_cats': '1',
#   'max_dwell': '2.391026534880309',
#   'mean_dwell': '1.2005153146952248',
#   'total_duration': '0.6078355878792042',
#   'click_rate': '0.0561372479568235',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013561420136448',
#   'prod_most_viewed_n_times': '16.0',
#   'prod_most_viewed': '1028809',
#   'cat_views_freqs': '1.5328373284689834e-06',
#   'prod_views_freqs': '0.0009611731128219',
#   'cat_buys_freqs': '0.0328798578820302',
#   'prod_buys_freqs': '0.0006900535468109',
#   'is_purchase': '0',
#   'start_time_ts': 'October 10, 2019 Thursday, 22:18:35',
#   'end_time_ts': 'October 16, 2019 Wednesday, 20:01:30'},
#  {'index': '7',
#   'user_session': 'e3887764-a39b-4377-b977-2f4e520a4849',
#   'total_clicks': '10',
#   'total_items': '2',
#   'total_cats': '4',
#   'max_dwell': '11.567453745958858',
#   'mean_dwell': '4.980244669477201',
#   'total_duration': '0.0201545952866542',
#   'click_rate': '0.7112516439223011',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013560570199296',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1004357',
#   'cat_views_freqs': '6.200583482912636e-06',
#   'prod_views_freqs': '0.0009453409681643',
#   'cat_buys_freqs': '0.4550292185895114',
#   'prod_buys_freqs': '0.0006894011723935',
#   'is_purchase': '0',
#   'start_time_ts': 'October 13, 2019 Sunday, 07:59:25',
#   'end_time_ts': 'October 13, 2019 Sunday, 04:02:42'},
#  {'index': '8',
#   'user_session': '8ecc8c53-b0f5-45fb-850a-d92c73ca45d2',
#   'total_clicks': '3',
#   'total_items': '2',
#   'total_cats': '2',
#   'max_dwell': '1.524405177796175',
#   'mean_dwell': '51.365034360337965',
#   'total_duration': '2.61766935116868',
#   'click_rate': '0.0263073945038331',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '3',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2060367302192147968',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '34062070',
#   'cat_views_freqs': '0.1073569768470795',
#   'prod_views_freqs': '0.0009455220279722',
#   'cat_buys_freqs': '0.0002449528031083',
#   'prod_buys_freqs': '0.0007366282136403',
#   'is_purchase': '0',
#   'start_time_ts': 'October 10, 2019 Thursday, 09:52:05',
#   'end_time_ts': 'October 31, 2019 Thursday, 11:13:33'},
#  {'index': '9',
#   'user_session': '4a344f8f-a75c-47d3-a732-7366401493d3',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.3150200427476977',
#   'mean_dwell': '14.63958291102887',
#   'total_duration': '2.987014799583104',
#   'click_rate': '0.0037204246900254',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '3',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013563707219968',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '28575102',
#   'cat_views_freqs': '0.2678088467786883',
#   'prod_views_freqs': '0.0009451941357785',
#   'cat_buys_freqs': '0.4550292185895114',
#   'prod_buys_freqs': '0.0006892279130259',
#   'is_purchase': '0',
#   'start_time_ts': 'October 08, 2019 Tuesday, 00:30:36',
#   'end_time_ts': 'October 27, 2019 Sunday, 04:19:38'},
#  {'index': '10',
#   'user_session': '51883d93-dac7-4ea9-8a11-d8898dfc8801',
#   'total_clicks': '9',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.4766400430442885',
#   'mean_dwell': '1.384932141988939',
#   'total_duration': '0.0807728417503399',
#   'click_rate': '0.01095707481815',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013601220844288',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '28981657',
#   'cat_views_freqs': '0.2678086138127222',
#   'prod_views_freqs': '0.0009395407434697',
#   'cat_buys_freqs': '0.0177834653425849',
#   'prod_buys_freqs': '0.0007090177087499',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 02:46:59',
#   'end_time_ts': 'October 19, 2019 Saturday, 20:42:18'},
#  {'index': '11',
#   'user_session': 'a61aa60b-7177-407d-9540-bd97f9762459',
#   'total_clicks': '5',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.103829658263566',
#   'mean_dwell': '2.361860824816721',
#   'total_duration': '0.0842907605248542',
#   'click_rate': '0.5710321219686129',
#   'day_of_week': '5',
#   'is_weekend': '1',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '11.0',
#   'cat_most_viewed': '2053013578354555136',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '58101314',
#   'cat_views_freqs': '0.2678088467786883',
#   'prod_views_freqs': '0.000946155731029',
#   'cat_buys_freqs': '0.0001688958199696',
#   'prod_buys_freqs': '0.0006891109869325',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 17:36:23',
#   'end_time_ts': 'October 10, 2019 Thursday, 02:32:26'},
#  {'index': '12',
#   'user_session': 'bc2fe3d3-5e88-49ce-a639-734994e7256e',
#   'total_clicks': '22',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '2.2088243323503183',
#   'mean_dwell': '4.301460859673128',
#   'total_duration': '0.0305357288648662',
#   'click_rate': '0.0824118304845641',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013557281245440',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '29462742',
#   'cat_views_freqs': '1.5328373284689834e-06',
#   'prod_views_freqs': '0.0009619099075518',
#   'cat_buys_freqs': '0.4550292185895114',
#   'prod_buys_freqs': '0.0007378024923674',
#   'is_purchase': '0',
#   'start_time_ts': 'October 04, 2019 Friday, 03:22:18',
#   'end_time_ts': 'October 11, 2019 Friday, 10:04:50'},
#  {'index': '13',
#   'user_session': '85b4a0a3-c97a-47f8-96ff-a8177a637cdd',
#   'total_clicks': '11',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '90.71684068467742',
#   'mean_dwell': '0.5054134217133799',
#   'total_duration': '0.1828796189392733',
#   'click_rate': '0.0569517407595859',
#   'day_of_week': '3',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013567341956864',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1004272',
#   'cat_views_freqs': '0.2678032720233883',
#   'prod_views_freqs': '0.0009454320298281',
#   'cat_buys_freqs': '2.0897208441214565e-05',
#   'prod_buys_freqs': '0.0007388030468998',
#   'is_purchase': '0',
#   'start_time_ts': 'October 02, 2019 Wednesday, 23:27:22',
#   'end_time_ts': 'October 22, 2019 Tuesday, 19:43:33'},
#  {'index': '14',
#   'user_session': '1fff20da-5457-4957-80af-944c59c43030',
#   'total_clicks': '20',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '2.588596594231372',
#   'mean_dwell': '3.576845193878745',
#   'total_duration': '0.338421311880168',
#   'click_rate': '0.1667233693207166',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013580126723072',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1003422',
#   'cat_views_freqs': '6.840716478673237e-05',
#   'prod_views_freqs': '0.0009625119014125',
#   'cat_buys_freqs': '0.4550270258456121',
#   'prod_buys_freqs': '0.0006905960796208',
#   'is_purchase': '0',
#   'start_time_ts': 'October 11, 2019 Friday, 07:11:33',
#   'end_time_ts': 'October 25, 2019 Friday, 12:37:20'},
#  {'index': '15',
#   'user_session': '590e4995-0015-4bc5-b82c-42ec08ce265b',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '2.4294849781875074',
#   'mean_dwell': '5.777524058605118',
#   'total_duration': '268.1240153683854',
#   'click_rate': '0.1168378642839665',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013558426648320',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1010889',
#   'cat_views_freqs': '0.2678088467786883',
#   'prod_views_freqs': '0.0009618221634801',
#   'cat_buys_freqs': '0.1062108877289106',
#   'prod_buys_freqs': '0.0007366613130672',
#   'is_purchase': '0',
#   'start_time_ts': 'October 06, 2019 Sunday, 09:23:41',
#   'end_time_ts': 'October 12, 2019 Saturday, 23:11:36'},
#  {'index': '16',
#   'user_session': '1a1cad24-aba3-40e4-965a-1c9636e47b12',
#   'total_clicks': '3',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '115.3730334674465',
#   'mean_dwell': '336.9726193376183',
#   'total_duration': '4.795020160667415',
#   'click_rate': '0.0773050001726863',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013561546963456',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1016991',
#   'cat_views_freqs': '0.013857901306246',
#   'prod_views_freqs': '0.0009464330837784',
#   'cat_buys_freqs': '0.0109984023519471',
#   'prod_buys_freqs': '0.0007386285297951',
#   'is_purchase': '0',
#   'start_time_ts': 'October 09, 2019 Wednesday, 22:51:00',
#   'end_time_ts': 'October 01, 2019 Tuesday, 22:47:10'},
#  {'index': '17',
#   'user_session': 'bdd958b8-7e6b-4d28-bc54-661e302d6983',
#   'total_clicks': '4',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.5394787300615468',
#   'mean_dwell': '4.243064467661064',
#   'total_duration': '316.4337277970912',
#   'click_rate': '0.0805436019687687',
#   'day_of_week': '2',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013559288566528',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1014738',
#   'cat_views_freqs': '0.0201784318308741',
#   'prod_views_freqs': '0.0009458492722043',
#   'cat_buys_freqs': '0.4550286583358416',
#   'prod_buys_freqs': '0.0006898132902625',
#   'is_purchase': '0',
#   'start_time_ts': 'October 06, 2019 Sunday, 13:39:20',
#   'end_time_ts': 'October 10, 2019 Thursday, 06:27:38'},
#  {'index': '18',
#   'user_session': 'e386e58a-a4c6-47cf-8ff5-f1a9a469ca80',
#   'total_clicks': '5',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '6.619689685817313',
#   'mean_dwell': '7.02851133533149',
#   'total_duration': '2.772644710828897',
#   'click_rate': '0.0952470761822867',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2060573221787741696',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '58316487',
#   'cat_views_freqs': '0.001278566570451',
#   'prod_views_freqs': '0.0009614094528076',
#   'cat_buys_freqs': '0.0001094175086408',
#   'prod_buys_freqs': '0.0006893652612664',
#   'is_purchase': '0',
#   'start_time_ts': 'October 02, 2019 Wednesday, 14:45:51',
#   'end_time_ts': 'October 31, 2019 Thursday, 00:12:41'},
#  {'index': '19',
#   'user_session': 'c1cf4712-1f45-4f38-96bb-10a31af2f796',
#   'total_clicks': '7',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '3.314213602373819',
#   'mean_dwell': '5.795007280113518',
#   'total_duration': '0.2074586635767821',
#   'click_rate': '0.0998238994038801',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '51.0',
#   'cat_most_viewed': '2053013561138290432',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '23707621',
#   'cat_views_freqs': '0.2678035935286185',
#   'prod_views_freqs': '0.0009455104196962',
#   'cat_buys_freqs': '0.0781339370766367',
#   'prod_buys_freqs': '0.000690305152918',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 03:15:55',
#   'end_time_ts': 'October 31, 2019 Thursday, 18:01:33'},
#  {'index': '20',
#   'user_session': '36cb3a82-4ebe-4ce5-948f-1764343321c4',
#   'total_clicks': '18',
#   'total_items': '3',
#   'total_cats': '1',
#   'max_dwell': '3.1927860665134578',
#   'mean_dwell': '6.740394385792365',
#   'total_duration': '0.5460678823032618',
#   'click_rate': '0.0832077913888071',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2081151812267783680',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1011694',
#   'cat_views_freqs': '0.2678088467786883',
#   'prod_views_freqs': '0.000945155837434',
#   'cat_buys_freqs': '3.6923595951032784e-06',
#   'prod_buys_freqs': '0.0006895977007493',
#   'is_purchase': '0',
#   'start_time_ts': 'October 05, 2019 Saturday, 09:12:57',
#   'end_time_ts': 'October 27, 2019 Sunday, 13:36:09'},
#  {'index': '21',
#   'user_session': '7d5d4d81-7c90-4591-bb41-e55dbee386cd',
#   'total_clicks': '3',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.7537586947440859',
#   'mean_dwell': '0.9398644396728648',
#   'total_duration': '3.1296892057852905',
#   'click_rate': '0.009219438019744',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013567284248576',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1002960',
#   'cat_views_freqs': '0.267805278812163',
#   'prod_views_freqs': '0.0009449840508375',
#   'cat_buys_freqs': '0.0003228079420693',
#   'prod_buys_freqs': '0.0006898967484289',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 02:29:55',
#   'end_time_ts': 'October 11, 2019 Friday, 01:02:26'},
#  {'index': '22',
#   'user_session': '4c285cbd-86b6-4033-8fc0-0e58a29891bc',
#   'total_clicks': '14',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '86.05558009157765',
#   'mean_dwell': '4.502786155683691',
#   'total_duration': '0.1903804435973015',
#   'click_rate': '0.0561404409112851',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013569821156608',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1003891',
#   'cat_views_freqs': '0.2678071719510032',
#   'prod_views_freqs': '0.0009452429724085',
#   'cat_buys_freqs': '0.0786336810200904',
#   'prod_buys_freqs': '0.0006895904224764',
#   'is_purchase': '0',
#   'start_time_ts': 'October 02, 2019 Wednesday, 02:26:09',
#   'end_time_ts': 'October 14, 2019 Monday, 18:13:53'},
#  {'index': '23',
#   'user_session': '24c5ec8e-5383-43bd-b8e7-27ceb3d5130e',
#   'total_clicks': '32',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '2.71641873638711',
#   'mean_dwell': '3.620591397681279',
#   'total_duration': '1.4714763703346438',
#   'click_rate': '0.0438196960048813',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013558999313920',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '1025050',
#   'cat_views_freqs': '8.68322931939225e-06',
#   'prod_views_freqs': '0.0009489363395269',
#   'cat_buys_freqs': '0.0007715062010646',
#   'prod_buys_freqs': '0.0006894613228142',
#   'is_purchase': '0',
#   'start_time_ts': 'October 09, 2019 Wednesday, 09:54:50',
#   'end_time_ts': 'October 29, 2019 Tuesday, 10:39:08'},
#  {'index': '24',
#   'user_session': '44980e90-f85d-4c1f-bccb-408cd058066c',
#   'total_clicks': '18',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '3.4683954838019875',
#   'mean_dwell': '2.455868187958001',
#   'total_duration': '2.2974499259958328',
#   'click_rate': '0.0687827452864716',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2175178569341827584',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '58376857',
#   'cat_views_freqs': '0.0017785554072126',
#   'prod_views_freqs': '0.0009449831936434',
#   'cat_buys_freqs': '0.0',
#   'prod_buys_freqs': '0.0006898226340883',
#   'is_purchase': '0',
#   'start_time_ts': 'October 13, 2019 Sunday, 17:42:54',
#   'end_time_ts': 'October 06, 2019 Sunday, 04:57:36'},
#  {'index': '25',
#   'user_session': '4d55b628-b456-4387-bb1e-05826062c1f0',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.414482038321706',
#   'mean_dwell': '1.009551612912451',
#   'total_duration': '0.9618977792097798',
#   'click_rate': '0.0687441366274865',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2054764479623840256',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1008000',
#   'cat_views_freqs': '0.002121982962941',
#   'prod_views_freqs': '0.000961590793511',
#   'cat_buys_freqs': '0.4550257822737484',
#   'prod_buys_freqs': '0.0006900025199071',
#   'is_purchase': '0',
#   'start_time_ts': 'October 02, 2019 Wednesday, 00:25:24',
#   'end_time_ts': 'October 17, 2019 Thursday, 04:08:02'},
#  {'index': '26',
#   'user_session': '1de19d95-19cd-42e9-a483-4e68c86416d7',
#   'total_clicks': '6',
#   'total_items': '3',
#   'total_cats': '1',
#   'max_dwell': '2.34676455565827',
#   'mean_dwell': '3.981341193826053',
#   'total_duration': '132.55089599386605',
#   'click_rate': '0.0938214152338652',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013558592592640',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '1014875',
#   'cat_views_freqs': '0.00089727600553',
#   'prod_views_freqs': '0.0009613981706946',
#   'cat_buys_freqs': '0.4550292185895114',
#   'prod_buys_freqs': '0.0006898064572567',
#   'is_purchase': '0',
#   'start_time_ts': 'October 05, 2019 Saturday, 13:32:06',
#   'end_time_ts': 'October 27, 2019 Sunday, 23:35:57'},
#  {'index': '27',
#   'user_session': 'eb7c57d6-413c-4745-81d2-2ca2e72dbb99',
#   'total_clicks': '6',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '289.9813656276428',
#   'mean_dwell': '4.181078093087672',
#   'total_duration': '1.390480453115995',
#   'click_rate': '0.0392743555010979',
#   'day_of_week': '1',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '6.0',
#   'cat_most_viewed': '2053013569749884416',
#   'prod_most_viewed_n_times': '15.0',
#   'prod_most_viewed': '1004381',
#   'cat_views_freqs': '1.5328373284689834e-06',
#   'prod_views_freqs': '0.0009456106069192',
#   'cat_buys_freqs': '0.0370670706150426',
#   'prod_buys_freqs': '0.0006905798881403',
#   'is_purchase': '0',
#   'start_time_ts': 'October 09, 2019 Wednesday, 22:14:06',
#   'end_time_ts': 'October 26, 2019 Saturday, 08:06:58'},
#  {'index': '28',
#   'user_session': 'edfe467a-3cac-4962-9dda-f7ae8d0c16f6',
#   'total_clicks': '5',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '2.628099413878441',
#   'mean_dwell': '5.732747690301164',
#   'total_duration': '0.0704480203731208',
#   'click_rate': '0.0256617430265438',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013560067564288',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '1028459',
#   'cat_views_freqs': '0.2678088467786883',
#   'prod_views_freqs': '0.0009458095918737',
#   'cat_buys_freqs': '0.0006180598004983',
#   'prod_buys_freqs': '0.0007375706003721',
#   'is_purchase': '0',
#   'start_time_ts': 'October 10, 2019 Thursday, 15:55:25',
#   'end_time_ts': 'October 09, 2019 Wednesday, 20:25:06'},
#  {'index': '29',
#   'user_session': '18a9550a-83a1-42ba-9579-5a9103d1d678',
#   'total_clicks': '5',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '1.0479259992706902',
#   'mean_dwell': '2.994353553557835',
#   'total_duration': '0.4190310607251302',
#   'click_rate': '0.0394182618507046',
#   'day_of_week': '1',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013568044902400',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1005705',
#   'cat_views_freqs': '0.027212508302004',
#   'prod_views_freqs': '0.0009461618421293',
#   'cat_buys_freqs': '9.932063414093416e-05',
#   'prod_buys_freqs': '0.0007371067953338',
#   'is_purchase': '0',
#   'start_time_ts': 'October 12, 2019 Saturday, 13:41:08',
#   'end_time_ts': 'October 08, 2019 Tuesday, 18:02:39'},
#  {'index': '30',
#   'user_session': '14484e81-203c-460d-a33b-20fadfd7295c',
#   'total_clicks': '4',
#   'total_items': '1',
#   'total_cats': '2',
#   'max_dwell': '0.6401351604576375',
#   'mean_dwell': '4.307423013556669',
#   'total_duration': '3.8576225343869712',
#   'click_rate': '0.0619008174688603',
#   'day_of_week': '1',
#   'is_weekend': '1',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013556535727104',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '33389251',
#   'cat_views_freqs': '0.2678082238172101',
#   'prod_views_freqs': '0.0009611132271347',
#   'cat_buys_freqs': '0.0535075131759172',
#   'prod_buys_freqs': '0.0006905283214649',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 03:46:36',
#   'end_time_ts': 'October 26, 2019 Saturday, 09:52:25'},
#  {'index': '31',
#   'user_session': '1ebdfa3c-55c5-4912-8bb2-2603fc434669',
#   'total_clicks': '5',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '8.731415763557104',
#   'mean_dwell': '6.681599391121117',
#   'total_duration': '0.2613029483819919',
#   'click_rate': '0.0721222500475885',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2119478676786637824',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1008192',
#   'cat_views_freqs': '0.2678088467786883',
#   'prod_views_freqs': '0.0009459218179584',
#   'cat_buys_freqs': '0.0309854580833682',
#   'prod_buys_freqs': '0.0006894835727322',
#   'is_purchase': '0',
#   'start_time_ts': 'October 09, 2019 Wednesday, 21:20:37',
#   'end_time_ts': 'October 18, 2019 Friday, 17:05:15'},
#  {'index': '32',
#   'user_session': '27d377c6-1814-4bbe-ac98-0ee547d7b8b8',
#   'total_clicks': '3',
#   'total_items': '7',
#   'total_cats': '1',
#   'max_dwell': '3.031253176231646',
#   'mean_dwell': '4.672210240322516',
#   'total_duration': '0.3764582489782042',
#   'click_rate': '0.0593605732633205',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013562226954752',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '24670311',
#   'cat_views_freqs': '1.8200378718302712e-06',
#   'prod_views_freqs': '0.0009449377419305',
#   'cat_buys_freqs': '0.0083259420002903',
#   'prod_buys_freqs': '0.0006898781178336',
#   'is_purchase': '0',
#   'start_time_ts': 'October 02, 2019 Wednesday, 02:30:25',
#   'end_time_ts': 'October 10, 2019 Thursday, 16:33:12'},
#  {'index': '33',
#   'user_session': 'f514197a-8608-4ca2-b070-596e85edb4d5',
#   'total_clicks': '23',
#   'total_items': '8',
#   'total_cats': '1',
#   'max_dwell': '5.68081680649902',
#   'mean_dwell': '0.641498178512764',
#   'total_duration': '0.1921011109536641',
#   'click_rate': '0.0798204194732954',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013567574771456',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '35433427',
#   'cat_views_freqs': '0.1298650930783029',
#   'prod_views_freqs': '0.0009615558411206',
#   'cat_buys_freqs': '4.192247525930393e-06',
#   'prod_buys_freqs': '0.0007385762649716',
#   'is_purchase': '0',
#   'start_time_ts': 'October 06, 2019 Sunday, 12:50:17',
#   'end_time_ts': 'October 24, 2019 Thursday, 07:24:25'},
#  {'index': '34',
#   'user_session': '75b6965c-886b-4efd-838d-317b9de6d83b',
#   'total_clicks': '7',
#   'total_items': '5',
#   'total_cats': '1',
#   'max_dwell': '3.846295962357188',
#   'mean_dwell': '3.447145854092588',
#   'total_duration': '0.0503038543619114',
#   'click_rate': '0.0876008613617484',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013561305959424',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '36486178',
#   'cat_views_freqs': '0.2678088467786883',
#   'prod_views_freqs': '0.00095438988803',
#   'cat_buys_freqs': '0.4550282850588046',
#   'prod_buys_freqs': '0.0006892395376736',
#   'is_purchase': '0',
#   'start_time_ts': 'October 08, 2019 Tuesday, 07:03:37',
#   'end_time_ts': 'October 20, 2019 Sunday, 02:13:42'},
#  {'index': '35',
#   'user_session': 'c02cb690-206c-47bf-ad7f-4e57acce7bca',
#   'total_clicks': '28',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '8.983749484908465',
#   'mean_dwell': '2.519603583552009',
#   'total_duration': '30.716252529937037',
#   'click_rate': '0.098033701530118',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013562021671936',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '26349392',
#   'cat_views_freqs': '2.1277043841069765e-05',
#   'prod_views_freqs': '0.0009454022572211',
#   'cat_buys_freqs': '0.2196923259726204',
#   'prod_buys_freqs': '0.0006894955056021',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 06:28:52',
#   'end_time_ts': 'October 06, 2019 Sunday, 18:24:54'},
#  {'index': '36',
#   'user_session': 'ccd0ff34-dc58-4764-8f01-d6ba469bbe42',
#   'total_clicks': '12',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '12.835748774852991',
#   'mean_dwell': '1.6978155427344066',
#   'total_duration': '0.7113158992100159',
#   'click_rate': '0.0989280009754907',
#   'day_of_week': '3',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013556776591872',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1017928',
#   'cat_views_freqs': '0.2677891935221997',
#   'prod_views_freqs': '0.0009614516425879',
#   'cat_buys_freqs': '0.4550277298184898',
#   'prod_buys_freqs': '0.0006897923278322',
#   'is_purchase': '0',
#   'start_time_ts': 'October 04, 2019 Friday, 01:06:46',
#   'end_time_ts': 'October 17, 2019 Thursday, 23:41:29'},
#  {'index': '37',
#   'user_session': 'a822b03e-2d9e-43af-86c9-f0259f928456',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.7975143391183767',
#   'mean_dwell': '8.669396820144366',
#   'total_duration': '18.70460455767759',
#   'click_rate': '0.0349115188008273',
#   'day_of_week': '1',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013559093513216',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1010810',
#   'cat_views_freqs': '0.0011884599115394',
#   'prod_views_freqs': '0.0009458521560926',
#   'cat_buys_freqs': '0.1840544594125724',
#   'prod_buys_freqs': '0.0006897065072841',
#   'is_purchase': '0',
#   'start_time_ts': 'October 09, 2019 Wednesday, 05:43:06',
#   'end_time_ts': 'October 19, 2019 Saturday, 07:46:14'},
#  {'index': '38',
#   'user_session': '00821c52-eb82-41f7-9fed-e76a2b0148c5',
#   'total_clicks': '22',
#   'total_items': '3',
#   'total_cats': '1',
#   'max_dwell': '5.371558008757997',
#   'mean_dwell': '3.6345230340059977',
#   'total_duration': '0.0594118709734418',
#   'click_rate': '0.0773159687083921',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013570484493824',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1004282',
#   'cat_views_freqs': '0.2678087590876076',
#   'prod_views_freqs': '0.00094605259906',
#   'cat_buys_freqs': '0.0',
#   'prod_buys_freqs': '0.0007413262193504',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 02:33:50',
#   'end_time_ts': 'October 31, 2019 Thursday, 21:45:44'},
#  {'index': '39',
#   'user_session': '6480ed94-c5e2-4e57-b678-66e22ce44174',
#   'total_clicks': '5',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.2931248044297162',
#   'mean_dwell': '0.1997898589341637',
#   'total_duration': '0.3549252431349192',
#   'click_rate': '0.0394830789419542',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013561332867328',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '28663183',
#   'cat_views_freqs': '0.2678036443777128',
#   'prod_views_freqs': '0.0009449100292123',
#   'cat_buys_freqs': '0.0027935180867106',
#   'prod_buys_freqs': '0.0006900606258659',
#   'is_purchase': '0',
#   'start_time_ts': 'October 07, 2019 Monday, 14:19:03',
#   'end_time_ts': 'October 23, 2019 Wednesday, 00:20:49'},
#  {'index': '40',
#   'user_session': '29a63b59-8499-493d-ba6c-718b2b5e5b45',
#   'total_clicks': '7',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.1740717363926452',
#   'mean_dwell': '61.94844711908258',
#   'total_duration': '0.2432058428051876',
#   'click_rate': '0.10382911494253',
#   'day_of_week': '4',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013557681250816',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1002820',
#   'cat_views_freqs': '0.0009468236727999',
#   'prod_views_freqs': '0.0009455422773109',
#   'cat_buys_freqs': '0.1593940273717245',
#   'prod_buys_freqs': '0.0006963313891241',
#   'is_purchase': '0',
#   'start_time_ts': 'October 07, 2019 Monday, 17:46:42',
#   'end_time_ts': 'October 19, 2019 Saturday, 12:07:59'},
#  {'index': '41',
#   'user_session': '78823927-b929-48e8-9bc7-f22b85e43963',
#   'total_clicks': '9',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '1.2534545199320353',
#   'mean_dwell': '5.525966907541052',
#   'total_duration': '0.217755120375218',
#   'click_rate': '0.0515348358185209',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2054500927179232768',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '15070703',
#   'cat_views_freqs': '0.0213172234547717',
#   'prod_views_freqs': '0.0009460832228412',
#   'cat_buys_freqs': '7.249808310696992e-06',
#   'prod_buys_freqs': '0.000690289583329',
#   'is_purchase': '0',
#   'start_time_ts': 'October 12, 2019 Saturday, 17:11:58',
#   'end_time_ts': 'October 13, 2019 Sunday, 11:06:27'},
#  {'index': '42',
#   'user_session': '342baa54-0123-4eb8-a4cd-281e44d88cd7',
#   'total_clicks': '6',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.1308736097226964',
#   'mean_dwell': '7.451069267200684',
#   'total_duration': '0.9072941020199944',
#   'click_rate': '0.0088977935054243',
#   'day_of_week': '3',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2068343125985466880',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '1015521',
#   'cat_views_freqs': '2.3085779723111544e-05',
#   'prod_views_freqs': '0.0009612444084146',
#   'cat_buys_freqs': '0.4550278154983581',
#   'prod_buys_freqs': '0.0006895292581423',
#   'is_purchase': '0',
#   'start_time_ts': 'October 09, 2019 Wednesday, 01:34:39',
#   'end_time_ts': 'October 19, 2019 Saturday, 15:23:43'},
#  {'index': '43',
#   'user_session': '97ff4b69-cee7-4714-aa69-29bab229ff11',
#   'total_clicks': '2',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '1.2359101939042814',
#   'mean_dwell': '9.61757855872488',
#   'total_duration': '0.6321612138181584',
#   'click_rate': '0.0719481433013191',
#   'day_of_week': '4',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2139270649776529920',
#   'prod_most_viewed_n_times': '14.0',
#   'prod_most_viewed': '1019297',
#   'cat_views_freqs': '0.2678057114749339',
#   'prod_views_freqs': '0.0009454101161597',
#   'cat_buys_freqs': '0.0036372070023206',
#   'prod_buys_freqs': '0.0006899912250319',
#   'is_purchase': '0',
#   'start_time_ts': 'October 08, 2019 Tuesday, 01:02:45',
#   'end_time_ts': 'October 21, 2019 Monday, 03:10:13'},
#  {'index': '44',
#   'user_session': '93758109-42d4-42ee-9c80-039be883d7ee',
#   'total_clicks': '27',
#   'total_items': '2',
#   'total_cats': '4',
#   'max_dwell': '1.974911987952882',
#   'mean_dwell': '1.188746420127999',
#   'total_duration': '3.2726739542189365',
#   'click_rate': '0.0232544923055359',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013583943137792',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '18588765',
#   'cat_views_freqs': '0.0403472134693479',
#   'prod_views_freqs': '0.0009451678047045',
#   'cat_buys_freqs': '0.4550276440036183',
#   'prod_buys_freqs': '0.0006904698489423',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 02:31:13',
#   'end_time_ts': 'October 11, 2019 Friday, 16:10:11'},
#  {'index': '45',
#   'user_session': '34be4dd0-3756-4e07-85c0-7c74584d23ad',
#   'total_clicks': '2',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.1343891542652908',
#   'mean_dwell': '0.2395392155930327',
#   'total_duration': '93.80153738102128',
#   'click_rate': '0.0926642360978201',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2174556776752497664',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1012268',
#   'cat_views_freqs': '1.9859424393864344e-06',
#   'prod_views_freqs': '0.000945719017752',
#   'cat_buys_freqs': '0.0242841844318638',
#   'prod_buys_freqs': '0.0006896165356309',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 10:37:18',
#   'end_time_ts': 'October 14, 2019 Monday, 08:25:09'},
#  {'index': '46',
#   'user_session': '70e7a162-8b89-408f-a3df-bc7cfda206c8',
#   'total_clicks': '6',
#   'total_items': '3',
#   'total_cats': '1',
#   'max_dwell': '6.271836641031881',
#   'mean_dwell': '0.8924867904323004',
#   'total_duration': '26.1158523182717',
#   'click_rate': '0.0501084645553385',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013568915567872',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1015468',
#   'cat_views_freqs': '0.2678085195595728',
#   'prod_views_freqs': '0.0009400620331332',
#   'cat_buys_freqs': '3.878877790976232e-05',
#   'prod_buys_freqs': '0.0006897695439481',
#   'is_purchase': '0',
#   'start_time_ts': 'October 04, 2019 Friday, 21:02:05',
#   'end_time_ts': 'October 12, 2019 Saturday, 22:04:35'},
#  {'index': '47',
#   'user_session': '3bcec042-3d23-4c2f-a6e4-53fe929b2010',
#   'total_clicks': '6',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.5310150318694054',
#   'mean_dwell': '0.7605202268692584',
#   'total_duration': '0.5210035086464454',
#   'click_rate': '0.0593155173466462',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013557749806080',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1011317',
#   'cat_views_freqs': '2.1865647150898223e-05',
#   'prod_views_freqs': '0.0009456841951278',
#   'cat_buys_freqs': '2.391175260473e-05',
#   'prod_buys_freqs': '0.0006897641076921',
#   'is_purchase': '0',
#   'start_time_ts': 'October 12, 2019 Saturday, 05:57:15',
#   'end_time_ts': 'October 21, 2019 Monday, 09:17:24'},
#  {'index': '48',
#   'user_session': '717b0235-096d-40f5-9eb5-36ad0b10aa54',
#   'total_clicks': '5',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '13.978529866117052',
#   'mean_dwell': '4.733688655441875',
#   'total_duration': '0.77563698542346',
#   'click_rate': '0.1137178486550238',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013559239827456',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '38240025',
#   'cat_views_freqs': '0.2678070970574802',
#   'prod_views_freqs': '0.0009455813130036',
#   'cat_buys_freqs': '0.4550286832534935',
#   'prod_buys_freqs': '0.0007379056793393',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 02:30:57',
#   'end_time_ts': 'October 15, 2019 Tuesday, 20:05:02'},
#  {'index': '49',
#   'user_session': '256f9cba-7fcd-4616-9195-e9d487f0a377',
#   'total_clicks': '4',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '5.001096218960378',
#   'mean_dwell': '5.139517611682111',
#   'total_duration': '39.00704119332328',
#   'click_rate': '0.090685506943337',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013563580091136',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1025718',
#   'cat_views_freqs': '2.588170889816777e-05',
#   'prod_views_freqs': '0.0009458119358187',
#   'cat_buys_freqs': '0.4550282294425875',
#   'prod_buys_freqs': '0.0006891424830978',
#   'is_purchase': '0',
#   'start_time_ts': 'October 05, 2019 Saturday, 10:22:36',
#   'end_time_ts': 'October 09, 2019 Wednesday, 21:56:15'},
#  {'index': '50',
#   'user_session': '8bef2784-c1c4-46d4-83bc-12e8b3da391f',
#   'total_clicks': '4',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '145.50045266543066',
#   'mean_dwell': '0.8132343490542215',
#   'total_duration': '0.0542757808472434',
#   'click_rate': '0.0220657417411873',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013559832026624',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1026995',
#   'cat_views_freqs': '0.0001263691000216',
#   'prod_views_freqs': '0.0009613051874174',
#   'cat_buys_freqs': '0.0159049890320437',
#   'prod_buys_freqs': '0.0006902454007077',
#   'is_purchase': '0',
#   'start_time_ts': 'October 10, 2019 Thursday, 16:37:39',
#   'end_time_ts': 'October 31, 2019 Thursday, 23:10:22'},
#  {'index': '51',
#   'user_session': '7982d8aa-4450-4666-b9d5-ec7a4a7e09cc',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.1049693823905311',
#   'mean_dwell': '18.70751758350524',
#   'total_duration': '0.3158867113400664',
#   'click_rate': '0.041739497008429',
#   'day_of_week': '2',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013565782404608',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '29068345',
#   'cat_views_freqs': '0.0115676908551556',
#   'prod_views_freqs': '0.0009456407425312',
#   'cat_buys_freqs': '1.298066029359335e-06',
#   'prod_buys_freqs': '0.000689723827097',
#   'is_purchase': '0',
#   'start_time_ts': 'October 08, 2019 Tuesday, 22:48:31',
#   'end_time_ts': 'October 27, 2019 Sunday, 08:46:26'},
#  {'index': '52',
#   'user_session': 'd9a3ce05-6467-40c7-b38d-6d8a75b9da9b',
#   'total_clicks': '2',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '141.5410766741593',
#   'mean_dwell': '430.63971050664367',
#   'total_duration': '4.178435268765266',
#   'click_rate': '0.0671066418562305',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013568070541056',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1009983',
#   'cat_views_freqs': '0.0565967016442152',
#   'prod_views_freqs': '0.0009450548246423',
#   'cat_buys_freqs': '0.0721736623473443',
#   'prod_buys_freqs': '0.0007386528443395',
#   'is_purchase': '0',
#   'start_time_ts': 'October 13, 2019 Sunday, 16:33:40',
#   'end_time_ts': 'October 19, 2019 Saturday, 07:49:04'},
#  {'index': '53',
#   'user_session': '3dc6b78a-68e1-4c23-ba49-0ab01911cc08',
#   'total_clicks': '20',
#   'total_items': '3',
#   'total_cats': '1',
#   'max_dwell': '0.1677084150518154',
#   'mean_dwell': '107.16483144237942',
#   'total_duration': '0.1365555283542262',
#   'click_rate': '0.0713755778484083',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013566362441472',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1010708',
#   'cat_views_freqs': '0.1027643217707851',
#   'prod_views_freqs': '0.0009458980420939',
#   'cat_buys_freqs': '0.4550276589159988',
#   'prod_buys_freqs': '0.0006895132307161',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 08:44:02',
#   'end_time_ts': 'October 09, 2019 Wednesday, 13:13:49'},
#  {'index': '54',
#   'user_session': '05b7174f-ed63-4826-b72d-27f164a6529d',
#   'total_clicks': '7',
#   'total_items': '2',
#   'total_cats': '7',
#   'max_dwell': '0.3505991702220669',
#   'mean_dwell': '6.705480805634872',
#   'total_duration': '12.270973211773995',
#   'click_rate': '0.0904824166835078',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013558919617280',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1011710',
#   'cat_views_freqs': '0.0019048717881275',
#   'prod_views_freqs': '0.0009451944192883',
#   'cat_buys_freqs': '0.049555383548067',
#   'prod_buys_freqs': '0.0007398062590468',
#   'is_purchase': '0',
#   'start_time_ts': 'October 04, 2019 Friday, 11:27:00',
#   'end_time_ts': 'October 11, 2019 Friday, 00:18:25'},
#  {'index': '55',
#   'user_session': 'd8d5e2b2-743e-4456-9d5b-db1b833159c2',
#   'total_clicks': '2',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.3065878266287986',
#   'mean_dwell': '1.0260033055959294',
#   'total_duration': '2.101965482502653',
#   'click_rate': '0.0231430701729661',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013614125373696',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1006071',
#   'cat_views_freqs': '4.190908256859749e-06',
#   'prod_views_freqs': '0.0009615936376998',
#   'cat_buys_freqs': '0.0563293673482878',
#   'prod_buys_freqs': '0.0006904234852371',
#   'is_purchase': '0',
#   'start_time_ts': 'October 15, 2019 Tuesday, 19:19:38',
#   'end_time_ts': 'October 18, 2019 Friday, 10:10:58'},
#  {'index': '56',
#   'user_session': '103bbd0d-f1df-499c-865f-7e4bc03dad23',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '3',
#   'max_dwell': '3.620311389580784',
#   'mean_dwell': '0.5554694653656541',
#   'total_duration': '3.410075069239346',
#   'click_rate': '0.0928466966641042',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013574873704192',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '13480801',
#   'cat_views_freqs': '1.6271994307398565e-06',
#   'prod_views_freqs': '0.000945587980069',
#   'cat_buys_freqs': '0.4550286635166262',
#   'prod_buys_freqs': '0.0006901859925761',
#   'is_purchase': '0',
#   'start_time_ts': 'October 07, 2019 Monday, 18:17:49',
# ...
#   'total_clicks': '7',
#   'total_items': '3',
#   'total_cats': '5',
#   'max_dwell': '8.649940932613548',
#   'mean_dwell': '0.5922830757927041',
#   'total_duration': '12.129589926273702',
#   'click_rate': '0.0332632285551013',
#   'day_of_week': '1',
#   'is_weekend': '0',
#   'is_special_day': '1',
#   'time_of_day': '3',
#   'cat_most_viewed_n_times': '1.0',
#   'cat_most_viewed': '2053013557878004992',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '19478080',
#   'cat_views_freqs': '0.0095642896867966',
#   'prod_views_freqs': '0.0009465659664963',
#   'cat_buys_freqs': '0.4550284349812654',
#   'prod_buys_freqs': '0.0006892339589257',
#   'is_purchase': '0',
#   'start_time_ts': 'October 04, 2019 Friday, 05:15:54',
#   'end_time_ts': 'October 15, 2019 Tuesday, 20:54:10'},
#  {'index': '982',
#   'user_session': 'f73e2b7e-efab-499b-83e0-542e3101bf14',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.6984392527532374',
#   'mean_dwell': '246.4538526543808',
#   'total_duration': '0.0880141613376629',
#   'click_rate': '0.0451808976112993',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2171800935761667072',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1002137',
#   'cat_views_freqs': '0.0007240492972191',
#   'prod_views_freqs': '0.0009460616293395',
#   'cat_buys_freqs': '1.080894797764187e-06',
#   'prod_buys_freqs': '0.000740257514387',
#   'is_purchase': '0',
#   'start_time_ts': 'October 03, 2019 Thursday, 10:55:31',
#   'end_time_ts': 'October 28, 2019 Monday, 17:45:15'},
#  {'index': '983',
#   'user_session': '80b1e501-e0a6-4e81-9505-085fbeb2634c',
#   'total_clicks': '10',
#   'total_items': '3',
#   'total_cats': '1',
#   'max_dwell': '2.98702749856868',
#   'mean_dwell': '1.358679367337922',
#   'total_duration': '0.024397702080708',
#   'click_rate': '0.0137266955179302',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '1',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013561922336512',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '30164110',
#   'cat_views_freqs': '0.2678079436342838',
#   'prod_views_freqs': '0.0009455159434419',
#   'cat_buys_freqs': '0.4550253923518997',
#   'prod_buys_freqs': '0.0006899296609685',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 03:15:06',
#   'end_time_ts': 'October 19, 2019 Saturday, 11:32:34'},
#  {'index': '984',
#   'user_session': '73a660d0-5b1f-4453-87a3-525f6937992d',
#   'total_clicks': '8',
#   'total_items': '2',
#   'total_cats': '6',
#   'max_dwell': '560.4222102910767',
#   'mean_dwell': '8.28403919609297',
#   'total_duration': '0.2022932019646665',
#   'click_rate': '0.0782115297657212',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013557802422784',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '31789298',
#   'cat_views_freqs': '1.948581795357951e-05',
#   'prod_views_freqs': '0.0009454459896726',
#   'cat_buys_freqs': '0.0667215972873922',
#   'prod_buys_freqs': '0.0007392154223402',
#   'is_purchase': '0',
#   'start_time_ts': 'October 08, 2019 Tuesday, 22:33:28',
#   'end_time_ts': 'October 13, 2019 Sunday, 17:39:14'},
#  {'index': '985',
#   'user_session': '518397e0-e604-4327-bf46-a7c3d3d125dc',
#   'total_clicks': '5',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '0.1496405719713785',
#   'mean_dwell': '2.063554195592306',
#   'total_duration': '0.4337812328131541',
#   'click_rate': '0.1147325243156269',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013574176478976',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '1004443',
#   'cat_views_freqs': '4.628906939659061e-05',
#   'prod_views_freqs': '0.0009452105551917',
#   'cat_buys_freqs': '0.0209945278763641',
#   'prod_buys_freqs': '0.0006899503459962',
#   'is_purchase': '0',
#   'start_time_ts': 'October 18, 2019 Friday, 07:23:00',
#   'end_time_ts': 'October 20, 2019 Sunday, 17:11:23'},
#  {'index': '986',
#   'user_session': 'fa93f90c-e494-475d-bb04-281b630cd18a',
#   'total_clicks': '4',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '2.9477263596632683',
#   'mean_dwell': '0.706946340190375',
#   'total_duration': '3.284258909933386',
#   'click_rate': '0.0744311327508777',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '3',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013557732400128',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '25223483',
#   'cat_views_freqs': '0.0815735556712424',
#   'prod_views_freqs': '0.0009451338076878',
#   'cat_buys_freqs': '0.0001444143473723',
#   'prod_buys_freqs': '0.0006897518354168',
#   'is_purchase': '0',
#   'start_time_ts': 'October 17, 2019 Thursday, 21:26:00',
#   'end_time_ts': 'October 10, 2019 Thursday, 10:10:00'},
#  {'index': '987',
#   'user_session': '8b69208e-7c64-422d-b670-5b9d82d25606',
#   'total_clicks': '13',
#   'total_items': '5',
#   'total_cats': '2',
#   'max_dwell': '3.9763691825796568',
#   'mean_dwell': '5.890651620995724',
#   'total_duration': '0.9487371626952468',
#   'click_rate': '0.0895959232376683',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '1.0',
#   'cat_most_viewed': '2053013568519607040',
#   'prod_most_viewed_n_times': '15.0',
#   'prod_most_viewed': '1012928',
#   'cat_views_freqs': '1.234672171146478e-05',
#   'prod_views_freqs': '0.0009450595293559',
#   'cat_buys_freqs': '0.0169334999556347',
#   'prod_buys_freqs': '0.0006894318963434',
#   'is_purchase': '0',
#   'start_time_ts': 'October 08, 2019 Tuesday, 14:43:14',
#   'end_time_ts': 'October 19, 2019 Saturday, 01:35:05'},
#  {'index': '988',
#   'user_session': '40452ab4-6d3e-4efb-935b-c8aa3126155d',
#   'total_clicks': '3',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '1.737725783581312',
#   'mean_dwell': '1.345691409547901',
#   'total_duration': '0.479250806027224',
#   'click_rate': '0.1007971249739612',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013557671196672',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1013979',
#   'cat_views_freqs': '0.2678087798306807',
#   'prod_views_freqs': '0.0009456344999779',
#   'cat_buys_freqs': '0.0032870158437941',
#   'prod_buys_freqs': '0.0006899539885249',
#   'is_purchase': '0',
#   'start_time_ts': 'October 06, 2019 Sunday, 11:23:27',
#   'end_time_ts': 'October 16, 2019 Wednesday, 10:46:44'},
#  {'index': '989',
#   'user_session': '089e74ec-7468-46a8-999e-90be06221a8b',
#   'total_clicks': '4',
#   'total_items': '27',
#   'total_cats': '1',
#   'max_dwell': '4.366682947909717',
#   'mean_dwell': '3.8456561052367353',
#   'total_duration': '0.5762789394097174',
#   'click_rate': '0.0503843942371065',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2053013626195281152',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1021203',
#   'cat_views_freqs': '0.075013077705389',
#   'prod_views_freqs': '0.0009465645154081',
#   'cat_buys_freqs': '0.0012625583937245',
#   'prod_buys_freqs': '0.0006895933737452',
#   'is_purchase': '0',
#   'start_time_ts': 'October 12, 2019 Saturday, 20:54:44',
#   'end_time_ts': 'October 13, 2019 Sunday, 20:26:05'},
#  {'index': '990',
#   'user_session': '4ab177ba-7601-4999-a020-105e12d4ab11',
#   'total_clicks': '18',
#   'total_items': '17',
#   'total_cats': '1',
#   'max_dwell': '7.4866713803175164',
#   'mean_dwell': '4.112340358710445',
#   'total_duration': '11.880840949788698',
#   'click_rate': '0.0181668141453893',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '1',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013562139414784',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '55049146',
#   'cat_views_freqs': '0.0004690033672214',
#   'prod_views_freqs': '0.0009450019320171',
#   'cat_buys_freqs': '0.0050299186098193',
#   'prod_buys_freqs': '0.0006899866317357',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 03:45:09',
#   'end_time_ts': 'October 31, 2019 Thursday, 14:11:33'},
#  {'index': '991',
#   'user_session': '99d30b45-ca2a-4d5c-b251-bca6b57bea19',
#   'total_clicks': '6',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.2829893992925031',
#   'mean_dwell': '7.911278981003813',
#   'total_duration': '0.0186137401595291',
#   'click_rate': '0.0687340736582819',
#   'day_of_week': '4',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2084901584697285632',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '28138679',
#   'cat_views_freqs': '0.2678084650747208',
#   'prod_views_freqs': '0.0009453725010973',
#   'cat_buys_freqs': '0.0005136964503971',
#   'prod_buys_freqs': '0.000689808548836',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 16:23:50',
#   'end_time_ts': 'October 15, 2019 Tuesday, 01:25:14'},
#  {'index': '992',
#   'user_session': '87ff4905-0d3a-4eb9-9cfc-68bbfd18e78d',
#   'total_clicks': '8',
#   'total_items': '2',
#   'total_cats': '1',
#   'max_dwell': '2.010875743574909',
#   'mean_dwell': '10.351469946144151',
#   'total_duration': '1.6680694970866523',
#   'click_rate': '0.1050733332371297',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013564301029120',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '27967872',
#   'cat_views_freqs': '0.0746548506593754',
#   'prod_views_freqs': '0.0009453687838661',
#   'cat_buys_freqs': '0.0027484189365093',
#   'prod_buys_freqs': '0.0007371837546583',
#   'is_purchase': '0',
#   'start_time_ts': 'October 08, 2019 Tuesday, 01:37:28',
#   'end_time_ts': 'October 19, 2019 Saturday, 12:32:52'},
#  {'index': '993',
#   'user_session': '6276e696-891c-4ac7-a28b-5d41a7e5ac63',
#   'total_clicks': '2',
#   'total_items': '2',
#   'total_cats': '2',
#   'max_dwell': '0.0439650660308398',
#   'mean_dwell': '2.0735235020057683',
#   'total_duration': '52.49313003233232',
#   'click_rate': '0.0414448049613871',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '1.0',
#   'cat_most_viewed': '2053013561817715712',
#   'prod_most_viewed_n_times': '12.0',
#   'prod_most_viewed': '1034491',
#   'cat_views_freqs': '0.2678082171541079',
#   'prod_views_freqs': '0.000944904988458',
#   'cat_buys_freqs': '0.4550235978039895',
#   'prod_buys_freqs': '0.0007388293750179',
#   'is_purchase': '0',
#   'start_time_ts': 'October 04, 2019 Friday, 08:38:57',
#   'end_time_ts': 'October 26, 2019 Saturday, 05:46:04'},
#  {'index': '994',
#   'user_session': '101329ca-9aed-417a-b3c6-7d0cd84fcca1',
#   'total_clicks': '2',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.7158235573895693',
#   'mean_dwell': '3.028322752961357',
#   'total_duration': '1.1400335798308152',
#   'click_rate': '0.0162579858299033',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013560133982720',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '31545595',
#   'cat_views_freqs': '0.0285057523352793',
#   'prod_views_freqs': '0.0009450951308255',
#   'cat_buys_freqs': '0.4550251017475966',
#   'prod_buys_freqs': '0.0006904055166523',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 02:31:13',
#   'end_time_ts': 'October 12, 2019 Saturday, 04:27:57'},
#  {'index': '995',
#   'user_session': 'c90c637c-260f-4008-9249-1b237b7cf96b',
#   'total_clicks': '4',
#   'total_items': '2',
#   'total_cats': '2',
#   'max_dwell': '0.4566587610220541',
#   'mean_dwell': '17.84509366660512',
#   'total_duration': '0.0853555718760269',
#   'click_rate': '0.1247445320326484',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '2.0',
#   'cat_most_viewed': '2053013561654170112',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '1014138',
#   'cat_views_freqs': '0.2677894847991127',
#   'prod_views_freqs': '0.0009460226212202',
#   'cat_buys_freqs': '0.0076910570135142',
#   'prod_buys_freqs': '0.0006891897683111',
#   'is_purchase': '0',
#   'start_time_ts': 'October 01, 2019 Tuesday, 05:29:06',
#   'end_time_ts': 'October 15, 2019 Tuesday, 22:15:27'},
#  {'index': '996',
#   'user_session': 'f26e014f-94ea-4e71-bb70-5176abe2bbed',
#   'total_clicks': '3',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '7.722973361485728',
#   'mean_dwell': '4.520130412618653',
#   'total_duration': '4.038310192634837',
#   'click_rate': '0.0726390594590674',
#   'day_of_week': '5',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '1',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2111841088799991552',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '22534233',
#   'cat_views_freqs': '0.2678084390422354',
#   'prod_views_freqs': '0.0009454895492304',
#   'cat_buys_freqs': '0.0657369715844385',
#   'prod_buys_freqs': '0.0006891506569975',
#   'is_purchase': '0',
#   'start_time_ts': 'October 04, 2019 Friday, 21:11:33',
#   'end_time_ts': 'October 08, 2019 Tuesday, 08:47:00'},
#  {'index': '997',
#   'user_session': '7515407e-6014-4889-b025-e3e8e9be4fc8',
#   'total_clicks': '12',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.6611007893992159',
#   'mean_dwell': '0.2152220548338592',
#   'total_duration': '0.0259278055236748',
#   'click_rate': '0.0377912186029675',
#   'day_of_week': '4',
#   'is_weekend': '1',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '24.0',
#   'cat_most_viewed': '2053013560021692160',
#   'prod_most_viewed_n_times': '2.0',
#   'prod_most_viewed': '1007584',
#   'cat_views_freqs': '0.0014170578218888',
#   'prod_views_freqs': '0.0009452453599532',
#   'cat_buys_freqs': '8.909815408832122e-05',
#   'prod_buys_freqs': '0.0006892225449379',
#   'is_purchase': '0',
#   'start_time_ts': 'October 03, 2019 Thursday, 10:59:37',
#   'end_time_ts': 'October 14, 2019 Monday, 03:03:10'},
#  {'index': '998',
#   'user_session': '667dc3c1-12de-4ba7-88fe-2618d48caefb',
#   'total_clicks': '26',
#   'total_items': '1',
#   'total_cats': '1',
#   'max_dwell': '0.9829999169196536',
#   'mean_dwell': '0.8965130899529755',
#   'total_duration': '3.61027652759726',
#   'click_rate': '0.0533957579908859',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '4.0',
#   'cat_most_viewed': '2092363484414324992',
#   'prod_most_viewed_n_times': '1.0',
#   'prod_most_viewed': '26453937',
#   'cat_views_freqs': '0.0414546047971869',
#   'prod_views_freqs': '0.000961356051548',
#   'cat_buys_freqs': '0.0004273911613021',
#   'prod_buys_freqs': '0.000689537912924',
#   'is_purchase': '0',
#   'start_time_ts': 'October 03, 2019 Thursday, 18:19:48',
#   'end_time_ts': 'October 12, 2019 Saturday, 08:28:59'},
#  {'index': '999',
#   'user_session': '1744b10d-6e74-4c26-b335-820a27c02dac',
#   'total_clicks': '12',
#   'total_items': '3',
#   'total_cats': '1',
#   'max_dwell': '0.3234185304838395',
#   'mean_dwell': '5.259994856597558',
#   'total_duration': '5.109863180845789',
#   'click_rate': '0.0740144254378595',
#   'day_of_week': '0',
#   'is_weekend': '0',
#   'is_special_day': '0',
#   'time_of_day': '2',
#   'cat_most_viewed_n_times': '3.0',
#   'cat_most_viewed': '2053013556282083072',
#   'prod_most_viewed_n_times': '3.0',
#   'prod_most_viewed': '1013006',
#   'cat_views_freqs': '0.0162849318602445',
#   'prod_views_freqs': '0.0009611768680542',
#   'cat_buys_freqs': '0.0788226885383789',
#   'prod_buys_freqs': '0.0006893939019204',
#   'is_purchase': '0',
#   'start_time_ts': 'October 08, 2019 Tuesday, 01:25:45',
#   'end_time_ts': 'October 25, 2019 Friday, 23:24:55'},
#  ...]

# %%
#the headers
HEADERS = ['index','user_session','total_clicks','total_items','total_cats','max_dwell','mean_dwell',
           'total_duration','click_rate','day_of_week','is_weekend','is_special_day','time_of_day',
           'cat_most_viewed_n_times','cat_most_viewed','prod_most_viewed_n_times','prod_most_viewed',
           'cat_views_freqs','prod_views_freqs','cat_buys_freqs','prod_buys_freqs','is_purchase',
           'start_time_ts','end_time_ts']

# %%
#convert to csv 

rows = []

for retail in retail_data_list:
    index = retail['index'] 
    user_session = retail['user_session']  
    total_clicks  = retail['total_clicks']  
    total_items = retail['total_items']  
    total_cats  = retail['total_cats']  
    max_dwell = retail['max_dwell']  
    mean_dwell = retail['mean_dwell']  
    total_duration = retail['total_duration']  
    click_rate = retail['click_rate']  
    day_of_week = retail['day_of_week']  
    is_weekend = retail['is_weekend']  
    is_special_day = retail['is_special_day']  
    time_of_day = retail['time_of_day']  
    cat_most_viewed_n_times = retail['cat_most_viewed_n_times']  
    cat_most_viewed = retail['cat_most_viewed']  
    prod_most_viewed_n_times = retail['prod_most_viewed_n_times']  
    prod_most_viewed = retail['prod_most_viewed']  
    cat_views_freqs = retail['cat_views_freqs']  
    prod_views_freqs = retail['prod_views_freqs']  
    cat_buys_freqs = retail['cat_buys_freqs']  
    prod_buys_freqs = retail['prod_buys_freqs']  
    is_purchase = retail['is_purchase']  
    start_time_ts = retail['start_time_ts']  
    end_time_ts = retail['end_time_ts']
    rows.append([index,user_session,total_clicks,total_items,total_cats,max_dwell,mean_dwell,total_duration,click_rate,day_of_week,is_weekend,is_special_day,time_of_day,cat_most_viewed_n_times,cat_most_viewed,prod_most_viewed_n_times,prod_most_viewed,cat_views_freqs,prod_views_freqs,cat_buys_freqs,prod_buys_freqs,is_purchase,start_time_ts,end_time_ts])
    
with open('retail_data.csv', 'w',newline="") as f:
    write = csv.writer(f)
    write.writerow(HEADERS)
    write.writerows(rows)

# %%
#read csv file created 
df = pd.read_csv('./retail_data.csv')

# %%
#check for missing values 
pd.isnull(df).sum()
# Out:
# index                       0
# user_session                0
# total_clicks                0
# total_items                 0
# total_cats                  0
# max_dwell                   0
# mean_dwell                  0
# total_duration              0
# click_rate                  0
# day_of_week                 0
# is_weekend                  0
# is_special_day              0
# time_of_day                 0
# cat_most_viewed_n_times     0
# cat_most_viewed             0
# prod_most_viewed_n_times    0
# prod_most_viewed            0
# cat_views_freqs             0
# prod_views_freqs            0
# cat_buys_freqs              0
# prod_buys_freqs             0
# is_purchase                 0
# start_time_ts               0
# end_time_ts                 0
# dtype: int64

# %%
#convert the data to a spark dataframe
df_1 = spark.createDataFrame(df)

# %%
#casting each data into their Datatype and we write the output as df_1
df_1 \
    .withColumn("index",F.col("index").cast(IntegerType())) \
    .withColumn("user_session",F.col("user_session").cast(StringType())) \
    .withColumn("total_clicks",F.col("total_clicks").cast(IntegerType())) \
    .withColumn("total_items",F.col("total_items").cast(IntegerType())) \
    .withColumn("total_cats",F.col("total_cats").cast(IntegerType())) \
    .withColumn("max_dwell",F.col("max_dwell").cast(DoubleType())) \
    .withColumn("mean_dwell",F.col("mean_dwell").cast(DoubleType())) \
    .withColumn("total_duration",F.col("total_duration").cast(DoubleType())) \
    .withColumn("click_rate",F.col("click_rate").cast(DoubleType())) \
    .withColumn("day_of_week",F.col("day_of_week").cast(IntegerType())) \
    .withColumn("is_weekend",F.col("is_weekend").cast(IntegerType())) \
    .withColumn("is_special_day",F.col("is_special_day").cast(IntegerType())) \
    .withColumn("time_of_day",F.col("time_of_day").cast(IntegerType())) \
    .withColumn("cat_most_viewed_n_times",F.col("cat_most_viewed_n_times").cast(IntegerType())) \
    .withColumn("cat_most_viewed",F.col("cat_most_viewed").cast(IntegerType())) \
    .withColumn("prod_most_viewed_n_times",F.col("prod_most_viewed_n_times").cast(IntegerType())) \
    .withColumn("prod_most_viewed",F.col("prod_most_viewed").cast(IntegerType())) \
    .withColumn("cat_views_freqs",F.col("cat_views_freqs").cast(DoubleType())) \
    .withColumn("prod_views_freqs",F.col("prod_views_freqs").cast(DoubleType())) \
    .withColumn("cat_buys_freqs",F.col("cat_buys_freqs").cast(DoubleType())) \
    .withColumn("prod_buys_freqs",F.col("prod_buys_freqs").cast(DoubleType())) \
    .withColumn("is_purchase",F.col("is_purchase").cast(IntegerType())) \
    .withColumn("start_time_ts",F.col("start_time_ts").cast(StringType())) \
    .withColumn("end_time_ts",F.col("end_time_ts").cast(StringType())) \
    .write.parquet('df_1', mode='overwrite')

# %%
#we read the new dataframe using the spark library
df_1 = spark.read.parquet('df_1')

# %% [markdown]
# ### #excercise 1 . .
# Process the "start_time_ts" column to create
# "time_spec_points" column. Allot exact points equaling the time
# of the day the user is surfing, but allot extra 5 points if they
# are surfing after 4 o clock in the afternoon. For example: If
# the user starts surfing at 9 o clock in the morning allot 9 points,
# but user surfing after 4 o clock in the afternoon will receive 21 points.

# %%
#function to get the hours and compare 
def compare(codate):
    codate = datetime.strptime(codate, "%B %d, %Y %A, %H:%M:%S")
    cotime = codate.time()
    hrs = "16:00:00"
    hrs = datetime.strptime(hrs, '%H:%M:%S')
    hrstime = hrs.time()
    print(hrstime)
    points = cotime.hour
    
    if cotime >= hrstime:
        return points + 5
    else: 
        return points
    
#convert function to UDF
compareudf = udf(lambda x: compare(x))

# %%
df_start_time_ts = df_1 \
    .select("start_time_ts","index") \
    .withColumn("time_spec_points", compareudf("start_time_ts"))

# %%
df_start_time_ts.show(10)
# Out:
# +--------------------+------+----------------+
# |       start_time_ts| index|time_spec_points|
# +--------------------+------+----------------+
# |October 09, 2019 ...|374784|              23|
# |October 01, 2019 ...|374785|               7|
# |October 02, 2019 ...|374786|              22|
# |October 06, 2019 ...|374787|              15|
# |October 13, 2019 ...|374788|              11|
# |October 04, 2019 ...|374789|               4|
# |October 05, 2019 ...|374790|               6|
# |October 04, 2019 ...|374791|              14|
# |October 04, 2019 ...|374792|              14|
# |October 01, 2019 ...|374793|               5|
# +--------------------+------+----------------+
# only showing top 10 rows

# %% [markdown]
# ### excercise 2
# Reduce the "total_duration" round to 2 decimal places: example (166.711175 -> 166.71) (0.935320 -> 0.94)

# %%
#round to 2dp
def round_up(x): 
    total = F.round(x,2)
    return total

# %%
df_total_duration = df_1 \
    .select("total_duration","index") \
    .withColumn("total_duration", round_up(("total_duration")))

# %%
df_total_duration.show(5)
# Out:
# +--------------+------+
# |total_duration| index|
# +--------------+------+
# |         10.45|374784|
# |          0.02|374785|
# |         31.17|374786|
# |          1.48|374787|
# |          0.02|374788|
# +--------------+------+
# only showing top 5 rows

# %% [markdown]
# ### excercise 3
# Add the values of columns  "total_clicks", "total_items", "total_cats" to create a new column: "total_inventory". If the value "total_inventory" is greater than 10, then make sure the value is increased by 100%.

# %%
#using UDF and lamba function
add_total = udf(lambda x,y,z: ((x + y + z) * 2) if (x + y + z) > 10  else (x + y + z))

# %%
df_total_inventory = df_1 \
    .select("total_clicks","total_items","total_cats") \
    .withColumn("total_inventory", add_total(("total_clicks"),("total_items"),("total_cats")))

# %%
df_total_inventory.show(5)
# Out:
# +------------+-----------+----------+---------------+
# |total_clicks|total_items|total_cats|total_inventory|
# +------------+-----------+----------+---------------+
# |          23|          2|         1|             52|
# |           4|          2|         1|              7|
# |           7|          2|         2|             22|
# |           2|          3|         1|              6|
# |          23|          2|         1|             52|
# +------------+-----------+----------+---------------+
# only showing top 5 rows

# %% [markdown]
# ### excercise 4
# Create a new column "give_big_discount". The value of '"give_big_discount" should be 1 if day_of_week is 0 and is_special_day is 1, otherwise 0.

# %%
#using lambda function to check condition
day_week  = udf(lambda x,y: 1 if (x == 0 and y == 1)   else 0 )

# %%
df_give_big_discount = df_1 \
    .select("index", "day_of_week", "is_special_day") \
    .withColumn("give_big_discount", day_week(("day_of_week"),("is_special_day")))

# %%
df_give_big_discount.show(500)
# Out:
# +------+-----------+--------------+-----------------+
# | index|day_of_week|is_special_day|give_big_discount|
# +------+-----------+--------------+-----------------+
# |374784|          5|             0|                0|
# |374785|          5|             0|                0|
# |374786|          5|             0|                0|
# |374787|          5|             1|                0|
# |374788|          5|             0|                0|
# |374789|          4|             0|                0|
# |374790|          3|             0|                0|
# |374791|          0|             0|                0|
# |374792|          1|             0|                0|
# |374793|          5|             0|                0|
# |374794|          5|             0|                0|
# |374795|          5|             0|                0|
# |374796|          5|             0|                0|
# |374797|          4|             0|                0|
# |374798|          5|             0|                0|
# |374799|          5|             0|                0|
# |374800|          6|             0|                0|
# |374801|          5|             0|                0|
# |374802|          5|             0|                0|
# |374803|          5|             0|                0|
# |374804|          0|             0|                0|
# |374805|          5|             0|                0|
# |374806|          5|             0|                0|
# |374807|          5|             0|                0|
# |374808|          1|             0|                0|
# |374809|          0|             0|                0|
# |374810|          5|             0|                0|
# |374811|          0|             0|                0|
# |374812|          5|             0|                0|
# |374813|          5|             1|                0|
# |374814|          5|             0|                0|
# |374815|          1|             0|                0|
# |374816|          5|             0|                0|
# |374817|          5|             0|                0|
# |374818|          5|             0|                0|
# |374819|          3|             0|                0|
# |374820|          0|             0|                0|
# |374821|          5|             0|                0|
# |374822|          5|             0|                0|
# |374823|          5|             0|                0|
# |374824|          5|             0|                0|
# |374825|          5|             0|                0|
# |374826|          0|             0|                0|
# |374827|          5|             0|                0|
# |374828|          5|             0|                0|
# |374829|          5|             0|                0|
# |374830|          5|             0|                0|
# |374831|          3|             0|                0|
# |374832|          3|             0|                0|
# |374833|          5|             0|                0|
# |374834|          0|             0|                0|
# |374835|          3|             0|                0|
# |374836|          5|             0|                0|
# |374837|          5|             0|                0|
# |374838|          5|             0|                0|
# |374839|          5|             0|                0|
# |374840|          0|             0|                0|
# |374841|          0|             0|                0|
# |374842|          5|             0|                0|
# |374843|          0|             0|                0|
# |374844|          5|             0|                0|
# |374845|          0|             0|                0|
# |374846|          5|             0|                0|
# |374847|          5|             0|                0|
# |374848|          5|             0|                0|
# |374849|          5|             0|                0|
# |374850|          5|             0|                0|
# |374851|          0|             0|                0|
# |374852|          2|             0|                0|
# |374853|          5|             0|                0|
# |374854|          0|             0|                0|
# |374855|          5|             0|                0|
# |374856|          5|             0|                0|
# |374857|          2|             1|                0|
# |374858|          5|             0|                0|
# |374859|          5|             0|                0|
# |374860|          5|             0|                0|
# |374861|          0|             0|                0|
# |374862|          5|             0|                0|
# |374863|          0|             0|                0|
# |374864|          5|             0|                0|
# |374865|          5|             0|                0|
# |374866|          0|             0|                0|
# |374867|          4|             0|                0|
# |374868|          5|             0|                0|
# |374869|          5|             0|                0|
# |374870|          5|             0|                0|
# |374871|          5|             0|                0|
# |374872|          5|             0|                0|
# |374873|          5|             0|                0|
# |374874|          5|             0|                0|
# |374875|          1|             0|                0|
# |374876|          5|             0|                0|
# |374877|          5|             0|                0|
# |374878|          5|             0|                0|
# |374879|          5|             0|                0|
# |374880|          5|             0|                0|
# |374881|          0|             0|                0|
# |374882|          5|             0|                0|
# |374883|          1|             0|                0|
# |374884|          5|             0|                0|
# |374885|          4|             0|                0|
# |374886|          5|             0|                0|
# |374887|          3|             0|                0|
# |374888|          5|             0|                0|
# |374889|          0|             0|                0|
# |374890|          0|             0|                0|
# |374891|          5|             0|                0|
# |374892|          3|             0|                0|
# |374893|          0|             0|                0|
# |374894|          0|             0|                0|
# |374895|          4|             0|                0|
# |374896|          5|             0|                0|
# |374897|          5|             0|                0|
# |374898|          0|             0|                0|
# |374899|          5|             0|                0|
# |374900|          5|             0|                0|
# |374901|          0|             0|                0|
# |374902|          0|             0|                0|
# |374903|          5|             0|                0|
# |374904|          2|             0|                0|
# |374905|          0|             0|                0|
# |374906|          1|             0|                0|
# |374907|          3|             0|                0|
# |374908|          5|             0|                0|
# |374909|          5|             0|                0|
# |374910|          5|             0|                0|
# |374911|          5|             0|                0|
# |374912|          5|             0|                0|
# |374913|          0|             0|                0|
# |374914|          5|             0|                0|
# |374915|          5|             0|                0|
# |374916|          0|             0|                0|
# |374917|          0|             1|                1|
# |374918|          0|             0|                0|
# |374919|          4|             0|                0|
# |374920|          3|             0|                0|
# |374921|          0|             0|                0|
# |374922|          0|             0|                0|
# |374923|          5|             0|                0|
# |374924|          5|             0|                0|
# |374925|          5|             0|                0|
# |374926|          5|             0|                0|
# |374927|          3|             0|                0|
# |374928|          5|             1|                0|
# |374929|          2|             0|                0|
# |374930|          5|             0|                0|
# |374931|          5|             0|                0|
# |374932|          5|             0|                0|
# |374933|          1|             0|                0|
# |374934|          5|             0|                0|
# |374935|          5|             0|                0|
# |374936|          1|             0|                0|
# |374937|          1|             0|                0|
# |374938|          5|             0|                0|
# |374939|          5|             0|                0|
# |374940|          5|             0|                0|
# |374941|          2|             0|                0|
# |374942|          0|             0|                0|
# |374943|          5|             0|                0|
# |374944|          0|             0|                0|
# |374945|          4|             0|                0|
# |374946|          3|             0|                0|
# |374947|          1|             0|                0|
# |374948|          5|             0|                0|
# |374949|          0|             0|                0|
# |374950|          1|             0|                0|
# |374951|          1|             0|                0|
# |374952|          5|             0|                0|
# |374953|          5|             0|                0|
# |374954|          5|             0|                0|
# |374955|          2|             0|                0|
# |374956|          5|             0|                0|
# |374957|          0|             0|                0|
# |374958|          5|             0|                0|
# |374959|          3|             0|                0|
# |374960|          5|             0|                0|
# |374961|          1|             0|                0|
# |374962|          3|             0|                0|
# |374963|          0|             0|                0|
# |374964|          5|             0|                0|
# |374965|          5|             0|                0|
# |374966|          3|             1|                0|
# |374967|          5|             0|                0|
# |374968|          5|             0|                0|
# |374969|          3|             1|                0|
# |374970|          5|             0|                0|
# |374971|          5|             0|                0|
# |374972|          5|             0|                0|
# |374973|          4|             0|                0|
# |374974|          5|             0|                0|
# |374975|          5|             0|                0|
# |374976|          5|             0|                0|
# |374977|          5|             0|                0|
# |374978|          1|             0|                0|
# |374979|          0|             1|                1|
# |374980|          2|             0|                0|
# |374981|          3|             1|                0|
# |374982|          0|             0|                0|
# |374983|          0|             0|                0|
# |374984|          5|             0|                0|
# |374985|          5|             0|                0|
# |374986|          3|             0|                0|
# |374987|          5|             0|                0|
# |374988|          0|             0|                0|
# |374989|          0|             0|                0|
# |374990|          5|             0|                0|
# |374991|          5|             0|                0|
# |374992|          5|             0|                0|
# |374993|          5|             0|                0|
# |374994|          4|             0|                0|
# |374995|          5|             0|                0|
# |374996|          5|             0|                0|
# |374997|          0|             0|                0|
# |374998|          0|             0|                0|
# |374999|          0|             0|                0|
# |375000|          3|             0|                0|
# |375001|          5|             0|                0|
# |375002|          0|             0|                0|
# |375003|          5|             0|                0|
# |375004|          3|             0|                0|
# |375005|          0|             0|                0|
# |375006|          0|             0|                0|
# |375007|          5|             1|                0|
# |375008|          5|             0|                0|
# |375009|          5|             0|                0|
# |375010|          5|             1|                0|
# |375011|          0|             0|                0|
# |375012|          5|             0|                0|
# |375013|          1|             0|                0|
# |375014|          2|             0|                0|
# |375015|          1|             0|                0|
# |375016|          0|             0|                0|
# |375017|          0|             0|                0|
# |375018|          5|             0|                0|
# |375019|          1|             0|                0|
# |375020|          5|             0|                0|
# |375021|          0|             0|                0|
# |375022|          0|             1|                1|
# |375023|          5|             0|                0|
# |375024|          0|             0|                0|
# |375025|          5|             0|                0|
# |375026|          5|             0|                0|
# |375027|          1|             0|                0|
# |375028|          5|             0|                0|
# |375029|          5|             0|                0|
# |375030|          0|             0|                0|
# |375031|          1|             0|                0|
# |375032|          0|             0|                0|
# |375033|          0|             0|                0|
# |375034|          0|             0|                0|
# |375035|          2|             0|                0|
# |375036|          0|             0|                0|
# |375037|          5|             0|                0|
# |375038|          5|             0|                0|
# |375039|          0|             1|                1|
# |375040|          0|             0|                0|
# |375041|          5|             0|                0|
# |375042|          5|             0|                0|
# |375043|          2|             0|                0|
# |375044|          0|             0|                0|
# |375045|          1|             0|                0|
# |375046|          5|             0|                0|
# |375047|          0|             0|                0|
# |375048|          5|             0|                0|
# |375049|          5|             0|                0|
# |375050|          0|             0|                0|
# |375051|          5|             0|                0|
# |375052|          5|             0|                0|
# |375053|          0|             0|                0|
# |375054|          4|             0|                0|
# |375055|          0|             0|                0|
# |375056|          5|             0|                0|
# |375057|          1|             0|                0|
# |375058|          0|             0|                0|
# |375059|          4|             0|                0|
# |375060|          0|             1|                1|
# |375061|          0|             1|                1|
# |375062|          5|             0|                0|
# |375063|          2|             0|                0|
# |375064|          5|             0|                0|
# |375065|          0|             0|                0|
# |375066|          5|             0|                0|
# |375067|          1|             0|                0|
# |375068|          5|             0|                0|
# |375069|          1|             0|                0|
# |375070|          2|             0|                0|
# |375071|          0|             0|                0|
# |375072|          1|             0|                0|
# |375073|          5|             0|                0|
# |375074|          0|             0|                0|
# |375075|          5|             0|                0|
# |375076|          0|             0|                0|
# |375077|          3|             0|                0|
# |375078|          0|             0|                0|
# |375079|          5|             0|                0|
# |375080|          0|             0|                0|
# |375081|          0|             1|                1|
# |375082|          5|             0|                0|
# |375083|          5|             0|                0|
# |375084|          5|             0|                0|
# |375085|          2|             0|                0|
# |375086|          5|             0|                0|
# |375087|          4|             0|                0|
# |375088|          5|             0|                0|
# |375089|          5|             0|                0|
# |375090|          5|             0|                0|
# |375091|          0|             0|                0|
# |375092|          0|             0|                0|
# |375093|          3|             0|                0|
# |375094|          5|             0|                0|
# |375095|          5|             0|                0|
# |375096|          5|             0|                0|
# |375097|          5|             0|                0|
# |375098|          0|             0|                0|
# |375099|          5|             0|                0|
# |375100|          0|             0|                0|
# |375101|          0|             0|                0|
# |375102|          0|             0|                0|
# |375103|          5|             0|                0|
# |375104|          5|             0|                0|
# |375105|          0|             0|                0|
# |375106|          0|             0|                0|
# |375107|          0|             0|                0|
# |375108|          5|             0|                0|
# |375109|          5|             0|                0|
# |375110|          5|             0|                0|
# |375111|          2|             0|                0|
# |375112|          0|             0|                0|
# |375113|          4|             0|                0|
# |375114|          5|             0|                0|
# |375115|          2|             0|                0|
# |375116|          0|             0|                0|
# |375117|          2|             0|                0|
# |375118|          5|             0|                0|
# |375119|          3|             0|                0|
# |375120|          0|             0|                0|
# |375121|          5|             0|                0|
# |375122|          0|             0|                0|
# |375123|          1|             0|                0|
# |375124|          0|             0|                0|
# |375125|          5|             0|                0|
# |375126|          3|             1|                0|
# |375127|          0|             0|                0|
# |375128|          5|             0|                0|
# |375129|          5|             1|                0|
# |375130|          0|             0|                0|
# |375131|          5|             0|                0|
# |375132|          5|             0|                0|
# |375133|          0|             0|                0|
# |375134|          1|             0|                0|
# |375135|          0|             0|                0|
# |375136|          5|             0|                0|
# |375137|          4|             0|                0|
# |375138|          5|             0|                0|
# |375139|          5|             0|                0|
# |375140|          1|             0|                0|
# |375141|          5|             0|                0|
# |375142|          0|             0|                0|
# |375143|          5|             0|                0|
# |375144|          5|             0|                0|
# |375145|          0|             1|                1|
# |375146|          5|             0|                0|
# |375147|          0|             0|                0|
# |375148|          5|             0|                0|
# |375149|          2|             0|                0|
# |375150|          5|             0|                0|
# |375151|          5|             0|                0|
# |375152|          1|             0|                0|
# |375153|          5|             0|                0|
# |375154|          5|             0|                0|
# |375155|          0|             0|                0|
# |375156|          3|             0|                0|
# |375157|          5|             0|                0|
# |375158|          0|             0|                0|
# |375159|          5|             0|                0|
# |375160|          5|             0|                0|
# |375161|          0|             0|                0|
# |375162|          3|             0|                0|
# |375163|          0|             0|                0|
# |375164|          3|             0|                0|
# |375165|          5|             0|                0|
# |375166|          0|             0|                0|
# |375167|          2|             0|                0|
# |375168|          5|             0|                0|
# |375169|          5|             0|                0|
# |375170|          5|             0|                0|
# |375171|          5|             0|                0|
# |375172|          5|             0|                0|
# |375173|          5|             0|                0|
# |375174|          5|             0|                0|
# |375175|          1|             0|                0|
# |375176|          5|             0|                0|
# |375177|          2|             0|                0|
# |375178|          0|             0|                0|
# |375179|          5|             0|                0|
# |375180|          1|             0|                0|
# |375181|          5|             0|                0|
# |375182|          1|             0|                0|
# |375183|          1|             0|                0|
# |375184|          2|             0|                0|
# |375185|          5|             0|                0|
# |375186|          5|             0|                0|
# |375187|          0|             0|                0|
# |375188|          4|             0|                0|
# |375189|          5|             0|                0|
# |375190|          5|             0|                0|
# |375191|          5|             0|                0|
# |375192|          5|             0|                0|
# |375193|          5|             0|                0|
# |375194|          5|             0|                0|
# |375195|          1|             0|                0|
# |375196|          5|             0|                0|
# |375197|          5|             0|                0|
# |375198|          5|             0|                0|
# |375199|          6|             0|                0|
# |375200|          5|             0|                0|
# |375201|          5|             0|                0|
# |375202|          3|             0|                0|
# |375203|          0|             0|                0|
# |375204|          5|             0|                0|
# |375205|          5|             0|                0|
# |375206|          5|             0|                0|
# |375207|          5|             0|                0|
# |375208|          0|             0|                0|
# |375209|          5|             1|                0|
# |375210|          4|             0|                0|
# |375211|          5|             0|                0|
# |375212|          0|             0|                0|
# |375213|          0|             0|                0|
# |375214|          5|             0|                0|
# |375215|          5|             0|                0|
# |375216|          5|             0|                0|
# |375217|          4|             0|                0|
# |375218|          5|             0|                0|
# |375219|          0|             0|                0|
# |375220|          0|             0|                0|
# |375221|          5|             0|                0|
# |375222|          3|             0|                0|
# |375223|          5|             0|                0|
# |375224|          5|             0|                0|
# |375225|          0|             0|                0|
# |375226|          5|             0|                0|
# |375227|          1|             0|                0|
# |375228|          5|             0|                0|
# |375229|          2|             0|                0|
# |375230|          5|             0|                0|
# |375231|          5|             0|                0|
# |375232|          5|             0|                0|
# |375233|          2|             1|                0|
# |375234|          1|             0|                0|
# |375235|          0|             0|                0|
# |375236|          5|             0|                0|
# |375237|          0|             1|                1|
# |375238|          0|             0|                0|
# |375239|          0|             0|                0|
# |375240|          5|             0|                0|
# |375241|          0|             0|                0|
# |375242|          5|             0|                0|
# |375243|          5|             0|                0|
# |375244|          0|             0|                0|
# |375245|          5|             0|                0|
# |375246|          0|             0|                0|
# |375247|          5|             0|                0|
# |375248|          5|             0|                0|
# |375249|          4|             1|                0|
# |375250|          5|             0|                0|
# |375251|          5|             0|                0|
# |375252|          0|             0|                0|
# |375253|          5|             0|                0|
# |375254|          5|             0|                0|
# |375255|          5|             0|                0|
# |375256|          4|             0|                0|
# |375257|          0|             0|                0|
# |375258|          5|             1|                0|
# |375259|          1|             0|                0|
# |375260|          0|             1|                1|
# |375261|          5|             0|                0|
# |375262|          0|             0|                0|
# |375263|          0|             0|                0|
# |375264|          5|             0|                0|
# |375265|          3|             0|                0|
# |375266|          5|             1|                0|
# |375267|          5|             0|                0|
# |375268|          5|             0|                0|
# |375269|          2|             0|                0|
# |375270|          3|             0|                0|
# |375271|          0|             0|                0|
# |375272|          5|             0|                0|
# |375273|          0|             0|                0|
# |375274|          0|             0|                0|
# |375275|          5|             0|                0|
# |375276|          5|             0|                0|
# |375277|          1|             0|                0|
# |375278|          5|             0|                0|
# |375279|          5|             0|                0|
# |375280|          1|             0|                0|
# |375281|          5|             0|                0|
# |375282|          5|             0|                0|
# |375283|          1|             0|                0|
# +------+-----------+--------------+-----------------+
# only showing top 500 rows

# %% [markdown]
# ### excercise 5
# Create a new column prod_views_buys_ratio which should be a ratio of prod_views_freqs and prod_buys_freqs

# %%
df_prod_views_buys_ratio = df_1 \
    .select("index", "prod_views_freqs", "prod_buys_freqs") \
    .withColumn("prod_views_buys_ratio", (df_1["prod_views_freqs"] / df_1["prod_buys_freqs"]))

# %%
df_prod_views_buys_ratio.show(5)
# Out:
# +------+-----------------+-----------------+---------------------+
# | index| prod_views_freqs|  prod_buys_freqs|prod_views_buys_ratio|
# +------+-----------------+-----------------+---------------------+
# |374784|9.451096233615E-4|6.903277846087E-4|   1.3690737131451525|
# |374785|9.451070075614E-4|7.388047267779E-4|    1.279237900498055|
# |374786|9.629738263031E-4|6.906869834825E-4|   1.3942261101370517|
# |374787|9.454285975401E-4|6.898934959078E-4|    1.370397899310607|
# |374788|9.457117763393E-4|  6.8940186458E-4|   1.3717859276685451|
# +------+-----------------+-----------------+---------------------+
# only showing top 5 rows

# %% [markdown]
# ### excercise 6
# Create a new column create loyalty_points which should be calculated based on the following conditions: if a user is spending more than 3 seconds on a Sunday -- and loyalty points score will be 10 multiplied seconds over 3.

# %%
def datecheck(codate):
    codate = datetime.strptime(codate, "%B %d, %Y %A, %H:%M:%S")
    cotimes = datetime.strftime(codate, "%A")
    return cotimes

# %%
#day_conv = udf(lambda x: day_conv(x))
checks = udf(lambda x: datecheck(x))

# %%
#function to check the if is a sunday and its more than 3 seconds 
loyal = udf(lambda x,y: ((10 * (x - 3)/3) if (x > 3 and y == 0) else 0))
#loyal = udf(lambda x,y: loyal(x,y))

# %%
df_loyalty_points = df_1 \
    .select("index","day_of_week", "start_time_ts", "end_time_ts","total_duration") \
    .withColumn("start_time_check", checks("start_time_ts")) \
    .withColumn("end_time_ts", checks("end_time_ts")) \
    .withColumn("loyalty_points", loyal(("total_duration"),("day_of_week")))

# %%
df_loyalty_points.show(100)
# Out:
# +------+-----------+--------------------+-----------+------------------+----------------+------------------+
# | index|day_of_week|       start_time_ts|end_time_ts|    total_duration|start_time_check|    loyalty_points|
# +------+-----------+--------------------+-----------+------------------+----------------+------------------+
# |374784|          5|October 09, 2019 ...|  Wednesday| 10.44792380395843|       Wednesday|                 0|
# |374785|          5|October 01, 2019 ...|     Monday|0.0211062899590174|         Tuesday|                 0|
# |374786|          5|October 02, 2019 ...|   Thursday| 31.16607832140132|       Wednesday|                 0|
# |374787|          5|October 06, 2019 ...|   Thursday|  1.48410645166671|          Sunday|                 0|
# |374788|          5|October 13, 2019 ...|     Monday|0.0188690047126103|          Sunday|                 0|
# |374789|          4|October 04, 2019 ...|    Tuesday| 3.164912354358772|          Friday|                 0|
# |374790|          3|October 05, 2019 ...|   Thursday|2.3356433963167773|        Saturday|                 0|
# |374791|          0|October 04, 2019 ...|   Saturday|6.2305438525020405|          Friday|10.768479508340135|
# |374792|          1|October 04, 2019 ...|    Tuesday| 3.444093515100824|          Friday|                 0|
# |374793|          5|October 01, 2019 ...|     Friday|0.8500037379947232|         Tuesday|                 0|
# |374794|          5|October 01, 2019 ...|     Monday|0.0317040853952791|         Tuesday|                 0|
# |374795|          5|October 01, 2019 ...|     Monday|  0.04445991875851|         Tuesday|                 0|
# |374796|          5|October 10, 2019 ...|  Wednesday|0.0180203969248598|        Thursday|                 0|
# |374797|          4|October 01, 2019 ...|     Sunday| 3.559026514104021|         Tuesday|                 0|
# |374798|          5|October 06, 2019 ...|   Thursday|1.5796767375666805|          Sunday|                 0|
# |374799|          5|October 04, 2019 ...|     Sunday|1.2105078692911564|          Friday|                 0|
# |374800|          6|October 03, 2019 ...|     Monday|13.640390934045106|        Thursday|                 0|
# |374801|          5|October 05, 2019 ...|     Sunday|0.4306063866963453|        Saturday|                 0|
# |374802|          5|October 04, 2019 ...|     Sunday|0.0299044620336558|          Friday|                 0|
# |374803|          5|October 04, 2019 ...|     Friday|0.1521421326020587|          Friday|                 0|
# |374804|          0|October 14, 2019 ...|  Wednesday|0.2181184289978498|          Monday|                 0|
# |374805|          5|October 03, 2019 ...|   Thursday| 0.595725320396071|        Thursday|                 0|
# |374806|          5|October 10, 2019 ...|    Tuesday|0.0375646741003151|        Thursday|                 0|
# |374807|          5|October 05, 2019 ...|     Sunday| 1.298545788286998|        Saturday|                 0|
# |374808|          1|October 04, 2019 ...|   Saturday|1.1624534989857511|          Friday|                 0|
# |374809|          0|October 10, 2019 ...|  Wednesday| 1.951708428453688|        Thursday|                 0|
# |374810|          5|October 13, 2019 ...|     Sunday|274.24745666717007|          Sunday|                 0|
# |374811|          0|October 10, 2019 ...|  Wednesday|0.0317835106496714|        Thursday|                 0|
# |374812|          5|October 01, 2019 ...|    Tuesday| 5.366202033531546|         Tuesday|                 0|
# |374813|          5|October 09, 2019 ...|   Saturday|0.5564601789396975|       Wednesday|                 0|
# |374814|          5|October 10, 2019 ...|     Monday|0.7847521607394293|        Thursday|                 0|
# |374815|          1|October 05, 2019 ...|    Tuesday|0.4071889729022794|        Saturday|                 0|
# |374816|          5|October 13, 2019 ...|    Tuesday|0.0227196085739178|          Sunday|                 0|
# |374817|          5|October 02, 2019 ...|  Wednesday|0.0514699223447311|       Wednesday|                 0|
# |374818|          5|October 04, 2019 ...|  Wednesday|0.7798609218085112|          Friday|                 0|
# |374819|          3|October 09, 2019 ...|  Wednesday| 2.200816197400669|       Wednesday|                 0|
# |374820|          0|October 02, 2019 ...|   Saturday| 1.779365815168337|       Wednesday|                 0|
# |374821|          5|October 02, 2019 ...|     Friday|2.9728867928548963|       Wednesday|                 0|
# |374822|          5|October 05, 2019 ...|   Thursday| 4.782585156839042|        Saturday|                 0|
# |374823|          5|October 01, 2019 ...|     Friday|0.1711343547237623|         Tuesday|                 0|
# |374824|          5|October 09, 2019 ...|   Thursday|10.159253366920574|       Wednesday|                 0|
# |374825|          5|October 02, 2019 ...|     Friday|0.5299408046681092|       Wednesday|                 0|
# |374826|          0|October 01, 2019 ...|  Wednesday| 3.619316188783367|         Tuesday|2.0643872959445573|
# |374827|          5|October 11, 2019 ...|     Sunday|0.4443107119168502|          Friday|                 0|
# |374828|          5|October 12, 2019 ...|   Thursday|0.0182301914776656|        Saturday|                 0|
# |374829|          5|October 07, 2019 ...|    Tuesday|0.1372773527238452|          Monday|                 0|
# |374830|          5|October 11, 2019 ...|     Sunday| 5.400777795250505|          Friday|                 0|
# |374831|          3|October 06, 2019 ...|     Monday|0.0179075801172602|          Sunday|                 0|
# |374832|          3|October 01, 2019 ...|  Wednesday| 34.02550468538863|         Tuesday|                 0|
# |374833|          5|October 14, 2019 ...|     Sunday| 43.04517891717124|          Monday|                 0|
# |374834|          0|October 02, 2019 ...|  Wednesday| 0.785868661962168|       Wednesday|                 0|
# |374835|          3|October 18, 2019 ...|  Wednesday|0.9668786030856166|          Friday|                 0|
# |374836|          5|October 06, 2019 ...|     Sunday| 3.615299897403469|          Sunday|                 0|
# |374837|          5|October 01, 2019 ...|     Friday|4.5142717517145705|         Tuesday|                 0|
# |374838|          5|October 01, 2019 ...|   Thursday|0.0263877532874841|         Tuesday|                 0|
# |374839|          5|October 08, 2019 ...|  Wednesday| 0.412218265161401|         Tuesday|                 0|
# |374840|          0|October 09, 2019 ...|   Saturday|14.075575990290297|       Wednesday|36.918586634300986|
# |374841|          0|October 01, 2019 ...|   Saturday|1.1724707300769304|         Tuesday|                 0|
# |374842|          5|October 07, 2019 ...|     Friday| 208.9876168855612|          Monday|                 0|
# |374843|          0|October 12, 2019 ...|    Tuesday| 6.607721605682062|        Saturday|12.025738685606873|
# |374844|          5|October 01, 2019 ...|     Friday|0.1630197911958921|         Tuesday|                 0|
# |374845|          0|October 10, 2019 ...|     Sunday|1.4406935052421173|        Thursday|                 0|
# |374846|          5|October 01, 2019 ...|   Thursday| 3.552686422080896|         Tuesday|                 0|
# |374847|          5|October 15, 2019 ...|    Tuesday|122.15462174378904|         Tuesday|                 0|
# |374848|          5|October 05, 2019 ...|   Saturday| 34.86293578592632|        Saturday|                 0|
# |374849|          5|October 10, 2019 ...|  Wednesday|24.627707789903464|        Thursday|                 0|
# |374850|          5|October 13, 2019 ...|     Friday| 40.91179291243526|          Sunday|                 0|
# |374851|          0|October 14, 2019 ...|   Thursday|0.0499211149181418|          Monday|                 0|
# |374852|          2|October 16, 2019 ...|     Friday|0.0207458327147213|       Wednesday|                 0|
# |374853|          5|October 03, 2019 ...|   Saturday|0.0260236951201011|        Thursday|                 0|
# |374854|          0|October 07, 2019 ...|   Thursday|0.0204813302461555|          Monday|                 0|
# |374855|          5|October 14, 2019 ...|     Monday|0.6357814200393017|          Monday|                 0|
# |374856|          5|October 13, 2019 ...|  Wednesday|0.4154525540855527|          Sunday|                 0|
# |374857|          2|October 01, 2019 ...|     Friday| 0.047755762154351|         Tuesday|                 0|
# |374858|          5|October 01, 2019 ...|   Thursday|0.1670402954438672|         Tuesday|                 0|
# |374859|          5|October 18, 2019 ...|     Sunday| 1.549477533715205|          Friday|                 0|
# |374860|          5|October 01, 2019 ...|  Wednesday| 1.964304202313804|         Tuesday|                 0|
# |374861|          0|October 05, 2019 ...|     Monday| 3.681259663733426|        Saturday| 2.270865545778086|
# |374862|          5|October 01, 2019 ...|   Thursday|0.3809345197246927|         Tuesday|                 0|
# |374863|          0|October 11, 2019 ...|     Friday| 314.6287398899284|          Friday|1038.7624662997614|
# |374864|          5|October 01, 2019 ...|  Wednesday|  5.34451177893092|         Tuesday|                 0|
# |374865|          5|October 13, 2019 ...|     Friday| 3.247752194560869|          Sunday|                 0|
# |374866|          0|October 03, 2019 ...|    Tuesday|1.6534750474257345|        Thursday|                 0|
# |374867|          4|October 11, 2019 ...|    Tuesday|3.1884808569357617|          Friday|                 0|
# |374868|          5|October 05, 2019 ...|   Thursday| 9.088742939787316|        Saturday|                 0|
# |374869|          5|October 10, 2019 ...|   Saturday|1.1970471423607116|        Thursday|                 0|
# |374870|          5|October 04, 2019 ...|   Saturday|10.453165363294532|          Friday|                 0|
# |374871|          5|October 06, 2019 ...|     Sunday|0.0242508537407091|          Sunday|                 0|
# |374872|          5|October 01, 2019 ...|  Wednesday|0.0217400663287132|         Tuesday|                 0|
# |374873|          5|October 01, 2019 ...|     Friday|7.9837555771993935|         Tuesday|                 0|
# |374874|          5|October 01, 2019 ...|     Friday|3.1498731360674896|         Tuesday|                 0|
# |374875|          1|October 07, 2019 ...|     Friday|0.0825957485402327|          Monday|                 0|
# |374876|          5|October 13, 2019 ...|   Saturday|0.1020619975707821|          Sunday|                 0|
# |374877|          5|October 01, 2019 ...|     Friday| 15.72036347408508|         Tuesday|                 0|
# |374878|          5|October 06, 2019 ...|    Tuesday|1.7832398276792325|          Sunday|                 0|
# |374879|          5|October 15, 2019 ...|   Thursday|1.6018364510841712|         Tuesday|                 0|
# |374880|          5|October 07, 2019 ...|     Friday|0.0312256245885994|          Monday|                 0|
# |374881|          0|October 08, 2019 ...|    Tuesday|1.7407091514494557|         Tuesday|                 0|
# |374882|          5|October 01, 2019 ...|   Thursday|1.4296941674042676|         Tuesday|                 0|
# |374883|          1|October 01, 2019 ...|    Tuesday|0.1123869844803026|         Tuesday|                 0|
# +------+-----------+--------------------+-----------+------------------+----------------+------------------+
# only showing top 100 rows

# %%
df_submit = df_1 \
    .select("index","is_special_day","prod_views_freqs","prod_buys_freqs","day_of_week","total_duration","total_clicks","total_items","total_cats","start_time_ts") \
    .withColumn("total_duration", round_up(("total_duration"))) \
    .withColumn("give_big_discount", day_week(("day_of_week"),("is_special_day"))) \
    .withColumn("prod_views_buys_ratio", (df_1["prod_views_freqs"] / df_1["prod_buys_freqs"])) \
    .withColumn("start_time_check", checks("start_time_ts")) \
    .withColumn("loyalty_points", loyal(("total_duration"),("day_of_week"))) \
    .withColumn("total_inventory", add_total(("total_clicks"),("total_items"),("total_cats"))) \
    .withColumn("time_spec_points", compareudf("start_time_ts"))

# %%
df_submit.show()
# Out:
# +------+--------------+-----------------+-----------------+-----------+--------------+------------+-----------+----------+--------------------+-----------------+---------------------+----------------+------------------+---------------+----------------+
# | index|is_special_day| prod_views_freqs|  prod_buys_freqs|day_of_week|total_duration|total_clicks|total_items|total_cats|       start_time_ts|give_big_discount|prod_views_buys_ratio|start_time_check|    loyalty_points|total_inventory|time_spec_points|
# +------+--------------+-----------------+-----------------+-----------+--------------+------------+-----------+----------+--------------------+-----------------+---------------------+----------------+------------------+---------------+----------------+
# |374784|             0|9.451096233615E-4|6.903277846087E-4|          5|         10.45|          23|          2|         1|October 09, 2019 ...|                0|   1.3690737131451525|       Wednesday|                 0|             52|              23|
# |374785|             0|9.451070075614E-4|7.388047267779E-4|          5|          0.02|           4|          2|         1|October 01, 2019 ...|                0|    1.279237900498055|         Tuesday|                 0|              7|               7|
# |374786|             0|9.629738263031E-4|6.906869834825E-4|          5|         31.17|           7|          2|         2|October 02, 2019 ...|                0|   1.3942261101370517|       Wednesday|                 0|             22|              22|
# |374787|             1|9.454285975401E-4|6.898934959078E-4|          5|          1.48|           2|          3|         1|October 06, 2019 ...|                0|    1.370397899310607|          Sunday|                 0|              6|              15|
# |374788|             0|9.457117763393E-4|  6.8940186458E-4|          5|          0.02|          23|          2|         1|October 13, 2019 ...|                0|   1.3717859276685451|          Sunday|                 0|             52|              11|
# |374789|             0|9.452400850668E-4|6.898850513427E-4|          4|          3.16|          18|          3|         1|October 04, 2019 ...|                0|   1.3701414217152716|          Friday|                 0|             44|               4|
# |374790|             0|9.450608108829E-4|6.894496371538E-4|          3|          2.34|          15|          3|         1|October 05, 2019 ...|                0|   1.3707466941085344|        Saturday|                 0|             38|               6|
# |374791|             0|9.457505759202E-4|6.894025278235E-4|          0|          6.23|          10|          2|         1|October 04, 2019 ...|                0|   1.3718408879439588|          Friday|10.766666666666667|             26|              14|
# |374792|             0|9.394761291956E-4|7.375698415549E-4|          1|          3.44|           2|          1|         1|October 04, 2019 ...|                0|   1.2737453136845367|          Friday|                 0|              4|              14|
# |374793|             0|9.458312108301E-4|6.896767631153E-4|          5|          0.85|           5|          2|         2|October 01, 2019 ...|                0|   1.3714123215602323|         Tuesday|                 0|              9|               5|
# |374794|             0|9.455896807332E-4|6.903364851903E-4|          5|          0.03|          12|          1|         1|October 01, 2019 ...|                0|   1.3697518543765455|         Tuesday|                 0|             28|               8|
# |374795|             0|9.462123147989E-4|6.890512028459E-4|          5|          0.04|           9|          1|         1|October 01, 2019 ...|                0|   1.3732104535786025|         Tuesday|                 0|             22|              22|
# |374796|             0|9.462747332722E-4|7.372511372317E-4|          5|          0.02|           2|          3|         3|October 10, 2019 ...|                0|    1.283517495578727|        Thursday|                 0|              8|               4|
# |374797|             0|9.617699314726E-4| 6.89621655607E-4|          4|          3.56|           5|          1|         1|October 01, 2019 ...|                0|   1.3946341789775396|         Tuesday|                 0|              7|               3|
# |374798|             0|9.451914508209E-4|6.901145861142E-4|          5|          1.58|           4|          3|         1|October 06, 2019 ...|                0|    1.369615234685809|          Sunday|                 0|              8|               1|
# |374799|             0|9.447653256867E-4|7.370932631302E-4|          5|          1.21|          15|          2|         4|October 04, 2019 ...|                0|   1.2817446216705102|          Friday|                 0|             42|              10|
# |374800|             0|9.455256887307E-4|7.383289050874E-4|          6|         13.64|          13|          2|         1|October 03, 2019 ...|                0|   1.2806293810463414|        Thursday|                 0|             32|              14|
# |374801|             0|9.456518533751E-4|6.895709517475E-4|          5|          0.43|          27|          2|         1|October 05, 2019 ...|                0|    1.371362658155254|        Saturday|                 0|             60|               4|
# |374802|             0|9.449834798047E-4|7.388140654805E-4|          5|          0.03|           3|          1|         1|October 04, 2019 ...|                0|   1.2790545334164887|          Friday|                 0|              5|              10|
# |374803|             0|9.617813022653E-4|7.385111411458E-4|          5|          0.15|           3|          2|         2|October 04, 2019 ...|                0|   1.3023247026078664|          Friday|                 0|              7|              22|
# +------+--------------+-----------------+-----------------+-----------+--------------+------------+-----------+----------+--------------------+-----------------+---------------------+----------------+------------------+---------------+----------------+
# only showing top 20 rows

# %%
df_sub = df_submit.toPandas()

# %%
df_sub
# Out:
#          index  is_special_day  prod_views_freqs  prod_buys_freqs  \
# 0       374784               0          0.000945         0.000690
# 1       374785               0          0.000945         0.000739
# 2       374786               0          0.000963         0.000691
# 3       374787               1          0.000945         0.000690
# 4       374788               0          0.000946         0.000689
# ...        ...             ...               ...              ...
# 499995  124923               0          0.000946         0.000691
# 499996  124924               0          0.000945         0.000690
# 499997  124925               0          0.000945         0.000690
# 499998  124926               0          0.000962         0.000690
# 499999  124927               0          0.000961         0.000738
#
#         day_of_week  total_duration  total_clicks  total_items  total_cats  \
# 0                 5           10.45            23            2           1
# 1                 5            0.02             4            2           1
# 2                 5           31.17             7            2           2
# 3                 5            1.48             2            3           1
# 4                 5            0.02            23            2           1
# ...             ...             ...           ...          ...         ...
# 499995            3            3.20             9            3           1
# 499996            4            5.84             6            3          10
# 499997            0            5.07            10            3           1
# 499998            4           10.54            17            2           1
# 499999            5            1.76             4            1           2
#
#                                start_time_ts give_big_discount  \
# 0       October 09, 2019 Wednesday, 18:53:59                 0
# 1         October 01, 2019 Tuesday, 07:16:43                 0
# 2       October 02, 2019 Wednesday, 17:50:25                 0
# 3          October 06, 2019 Sunday, 15:19:44                 0
# 4          October 13, 2019 Sunday, 11:38:09                 0
# ...                                      ...               ...
# 499995  October 02, 2019 Wednesday, 11:03:16                 0
# 499996   October 12, 2019 Saturday, 14:46:48                 0
# 499997   October 05, 2019 Saturday, 07:34:43                 0
# 499998     October 11, 2019 Friday, 22:37:47                 0
# 499999  October 09, 2019 Wednesday, 21:56:11                 0
#
#         prod_views_buys_ratio start_time_check     loyalty_points  \
# 0                    1.369074        Wednesday                  0
# 1                    1.279238          Tuesday                  0
# 2                    1.394226        Wednesday                  0
# 3                    1.370398           Sunday                  0
# 4                    1.371786           Sunday                  0
# ...                       ...              ...                ...
# 499995               1.369345        Wednesday                  0
# 499996               1.368773         Saturday                  0
# 499997               1.369833         Saturday  6.900000000000001
# 499998               1.393645           Friday                  0
# 499999               1.301580        Wednesday                  0
#
#        total_inventory time_spec_points
# 0                   52               23
# 1                    7                7
# 2                   22               22
# 3                    6               15
# 4                   52               11
# ...                ...              ...
# 499995              26               11
# 499996              38               14
# 499997              28                7
# 499998              40               27
# 499999               7               26
#
# [500000 rows x 16 columns]

# %%
df_sub_sort = df_sub.sort_values(by='index', ascending=True)

# %%
cols = ["total_duration","is_special_day","prod_views_freqs","prod_buys_freqs","give_big_discount","prod_views_buys_ratio","loyalty_points","total_inventory","time_spec_points"]

# %%
df_Final = df_sub_sort[cols]

# %%
df_Final.head(100)
# Out:
#         total_duration  is_special_day  prod_views_freqs  prod_buys_freqs  \
# 375072          166.71               0          0.000945         0.000690
# 375073            0.43               0          0.000946         0.000690
# 375074            0.94               0          0.000945         0.000690
# 375075            0.42               0          0.000945         0.000739
# 375076            2.49               0          0.000945         0.000690
# ...                ...             ...               ...              ...
# 375167            0.72               0          0.000945         0.000696
# 375168            1.21               0          0.000947         0.000689
# 375169            0.40               0          0.000961         0.000720
# 375170           29.18               0          0.000945         0.000690
# 375171            0.52               0          0.000946         0.000689
#
#        give_big_discount  prod_views_buys_ratio     loyalty_points  \
# 375072                 0               1.369726                  0
# 375073                 0               1.371440                  0
# 375074                 0               1.369958                  0
# 375075                 0               1.279051                  0
# 375076                 0               1.370596                  0
# ...                  ...                    ...                ...
# 375167                 0               1.356926                  0
# 375168                 0               1.373984                  0
# 375169                 0               1.334614                  0
# 375170                 0               1.369492  87.26666666666667
# 375171                 0               1.371746                  0
#
#        total_inventory time_spec_points
# 375072              10                0
# 375073              10               15
# 375074              50               26
# 375075               5               26
# 375076               7               13
# ...                ...              ...
# 375167               5               27
# 375168              78               11
# 375169              22               23
# 375170              44                3
# 375171              42               27
#
# [100 rows x 9 columns]

# %%
df_Final.to_csv("submitt-3.csv",index=False)

# %%
df = pd.read_csv("submitt-3.csv")

# %%
df.head(100)
# Out:
#     total_duration  is_special_day  prod_views_freqs  prod_buys_freqs  \
# 0           166.71               0          0.000945         0.000690
# 1             0.43               0          0.000946         0.000690
# 2             0.94               0          0.000945         0.000690
# 3             0.42               0          0.000945         0.000739
# 4             2.49               0          0.000945         0.000690
# ..             ...             ...               ...              ...
# 95            0.72               0          0.000945         0.000696
# 96            1.21               0          0.000947         0.000689
# 97            0.40               0          0.000961         0.000720
# 98           29.18               0          0.000945         0.000690
# 99            0.52               0          0.000946         0.000689
#
#     give_big_discount  prod_views_buys_ratio  loyalty_points  total_inventory  \
# 0                   0               1.369726        0.000000               10
# 1                   0               1.371440        0.000000               10
# 2                   0               1.369958        0.000000               50
# 3                   0               1.279051        0.000000                5
# 4                   0               1.370596        0.000000                7
# ..                ...                    ...             ...              ...
# 95                  0               1.356926        0.000000                5
# 96                  0               1.373984        0.000000               78
# 97                  0               1.334614        0.000000               22
# 98                  0               1.369492       87.266667               44
# 99                  0               1.371746        0.000000               42
#
#     time_spec_points
# 0                  0
# 1                 15
# 2                 26
# 3                 26
# 4                 13
# ..               ...
# 95                27
# 96                11
# 97                23
# 98                 3
# 99                27
#
# [100 rows x 9 columns]
